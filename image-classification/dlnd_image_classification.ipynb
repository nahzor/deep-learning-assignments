# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import numpy as np
import tensorflow as tf

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    arr = np.zeros(shape=x.shape)
    logits = tf.placeholder(tf.float32)
    softmax = tf.nn.softmax(logits)
    a = 0
    b = 1
    grayscale_min = 0
    grayscale_max = 255
        
    for i in range(0, len(x)):
        arr[i] = a + ( ( (x[i] - grayscale_min)*(b - a) )/( grayscale_max - grayscale_min ) )
        
    return arr
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing

t = None

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    labels = np.zeros((len(x), 10))
    for i in range(len(x)):
        labels[i,x[i]] = 1
    
    return labels


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    print(list(image_shape))
    
    return tf.placeholder(tf.float32,[None]+ list(image_shape), "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None] + [n_classes], "y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, None, "keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# [32, 32, 3]
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    xshape = x_tensor.get_shape().as_list()
    print(xshape)
    shape = list(conv_ksize + (xshape[-1],) + (conv_num_outputs,))
    print(shape)
    mean = 0
    stddev = 0.1
    strides = list((1,)+conv_strides+(1,)) # (batch, height, width, depth)
    conv_filter = tf.Variable(tf.truncated_normal(shape,mean,stddev))
    conv_layer = tf.nn.conv2d(x_tensor, conv_filter, strides, 'SAME')
    
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    
    conv_layer = tf.nn.relu(conv_layer)
    
    conv_layer = tf.nn.max_pool(
        conv_layer,
        ksize=list((1,)+pool_ksize+(1,)),
        strides=list((1,)+pool_strides+(1,)),
        padding='SAME')
    
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# [None, 32, 32, 5]
# [2, 2, 5, 10]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
from numpy import prod
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    # pass '[-1]' to flatten 't'
    out = tf.reshape(x_tensor,[-1,prod(shape[1:])])
    
    shape = out.get_shape().as_list() 
    print(shape)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# [None, 1800]
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    batch = x_tensor.get_shape().as_list()[-1]
    shape = list( (batch,) + (num_outputs,))
    print(shape)
    mean = 0
    stddev = 0.1
    weight = tf.Variable(tf.truncated_normal(shape,mean,stddev))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.nn.relu(tf.add(tf.matmul(x_tensor,weight), bias))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# [128, 40]
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    batch = x_tensor.get_shape().as_list()[-1]
    shape = list( (batch,) + (num_outputs,))
    print(shape)
    mean = 0
    stddev = 0.1
    weight = tf.Variable(tf.truncated_normal(shape,mean,stddev))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor,weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# [128, 40]
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    new_tensor = conv2d_maxpool(x, conv_num_outputs=20, conv_ksize=(4,4), conv_strides=(1,1), pool_ksize=(8,8), pool_strides=(1,1))
    
    new_tensor = tf.nn.dropout(new_tensor, keep_prob)
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    new_tensor = flatten(new_tensor)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    new_tensor = fully_conn(new_tensor, num_outputs=350)
    new_tensor = tf.nn.dropout(new_tensor, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    new_tensor = output(new_tensor,num_outputs=10)

    
    # TODO: return output
    return new_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# [32, 32, 3]
# [None, 32, 32, 3]
# [4, 4, 3, 20]
# [None, 20480]
# [20480, 350]
# [350, 10]
# [None, 32, 32, 3]
# [4, 4, 3, 20]
# [None, 20480]
# [20480, 350]
# [350, 10]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    vAcc = sess.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print('loss:')
    print(loss)
    print('Validation Accuracy:')
    print(vAcc)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 140
batch_size = 512
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss:
# 2.30264
# Validation Accuracy:
# 0.0946
# Epoch  2, CIFAR-10 Batch 1:  loss:
# 2.30264
# Validation Accuracy:
# 0.105
# Epoch  3, CIFAR-10 Batch 1:  loss:
# 2.2992
# Validation Accuracy:
# 0.1304
# Epoch  4, CIFAR-10 Batch 1:  loss:
# 2.28382
# Validation Accuracy:
# 0.1558
# Epoch  5, CIFAR-10 Batch 1:  loss:
# 2.27165
# Validation Accuracy:
# 0.1678
# Epoch  6, CIFAR-10 Batch 1:  loss:
# 2.23657
# Validation Accuracy:
# 0.1836
# Epoch  7, CIFAR-10 Batch 1:  loss:
# 2.23422
# Validation Accuracy:
# 0.1908
# Epoch  8, CIFAR-10 Batch 1:  loss:
# 2.19112
# Validation Accuracy:
# 0.2348
# Epoch  9, CIFAR-10 Batch 1:  loss:
# 2.13696
# Validation Accuracy:
# 0.2618
# Epoch 10, CIFAR-10 Batch 1:  loss:
# 2.08911
# Validation Accuracy:
# 0.2872
# Epoch 11, CIFAR-10 Batch 1:  loss:
# 2.01236
# Validation Accuracy:
# 0.3462
# Epoch 12, CIFAR-10 Batch 1:  loss:
# 1.94242
# Validation Accuracy:
# 0.3498
# Epoch 13, CIFAR-10 Batch 1:  loss:
# 1.9296
# Validation Accuracy:
# 0.3346
# Epoch 14, CIFAR-10 Batch 1:  loss:
# 1.88492
# Validation Accuracy:
# 0.3566
# Epoch 15, CIFAR-10 Batch 1:  loss:
# 1.83397
# Validation Accuracy:
# 0.3774
# Epoch 16, CIFAR-10 Batch 1:  loss:
# 1.80801
# Validation Accuracy:
# 0.3894
# Epoch 17, CIFAR-10 Batch 1:  loss:
# 1.79005
# Validation Accuracy:
# 0.3922
# Epoch 18, CIFAR-10 Batch 1:  loss:
# 1.75848
# Validation Accuracy:
# 0.4
# Epoch 19, CIFAR-10 Batch 1:  loss:
# 1.71986
# Validation Accuracy:
# 0.4302
# Epoch 20, CIFAR-10 Batch 1:  loss:
# 1.68382
# Validation Accuracy:
# 0.435
# Epoch 21, CIFAR-10 Batch 1:  loss:
# 1.66399
# Validation Accuracy:
# 0.444
# Epoch 22, CIFAR-10 Batch 1:  loss:
# 1.6102
# Validation Accuracy:
# 0.461
# Epoch 23, CIFAR-10 Batch 1:  loss:
# 1.61697
# Validation Accuracy:
# 0.4522
# Epoch 24, CIFAR-10 Batch 1:  loss:
# 1.56228
# Validation Accuracy:
# 0.4616
# Epoch 25, CIFAR-10 Batch 1:  loss:
# 1.5505
# Validation Accuracy:
# 0.4588
# Epoch 26, CIFAR-10 Batch 1:  loss:
# 1.52903
# Validation Accuracy:
# 0.4698
# Epoch 27, CIFAR-10 Batch 1:  loss:
# 1.5069
# Validation Accuracy:
# 0.472
# Epoch 28, CIFAR-10 Batch 1:  loss:
# 1.49059
# Validation Accuracy:
# 0.481
# Epoch 29, CIFAR-10 Batch 1:  loss:
# 1.4766
# Validation Accuracy:
# 0.4862
# Epoch 30, CIFAR-10 Batch 1:  loss:
# 1.4447
# Validation Accuracy:
# 0.4892
# Epoch 31, CIFAR-10 Batch 1:  loss:
# 1.43608
# Validation Accuracy:
# 0.499
# Epoch 32, CIFAR-10 Batch 1:  loss:
# 1.40068
# Validation Accuracy:
# 0.5002
# Epoch 33, CIFAR-10 Batch 1:  loss:
# 1.40616
# Validation Accuracy:
# 0.501
# Epoch 34, CIFAR-10 Batch 1:  loss:
# 1.38903
# Validation Accuracy:
# 0.5
# Epoch 35, CIFAR-10 Batch 1:  loss:
# 1.38726
# Validation Accuracy:
# 0.5072
# Epoch 36, CIFAR-10 Batch 1:  loss:
# 1.33979
# Validation Accuracy:
# 0.5098
# Epoch 37, CIFAR-10 Batch 1:  loss:
# 1.32093
# Validation Accuracy:
# 0.5218
# Epoch 38, CIFAR-10 Batch 1:  loss:
# 1.3043
# Validation Accuracy:
# 0.5266
# Epoch 39, CIFAR-10 Batch 1:  loss:
# 1.30988
# Validation Accuracy:
# 0.5194
# Epoch 40, CIFAR-10 Batch 1:  loss:
# 1.26243
# Validation Accuracy:
# 0.5294
# Epoch 41, CIFAR-10 Batch 1:  loss:
# 1.25058
# Validation Accuracy:
# 0.5354
# Epoch 42, CIFAR-10 Batch 1:  loss:
# 1.25975
# Validation Accuracy:
# 0.5344
# Epoch 43, CIFAR-10 Batch 1:  loss:
# 1.24076
# Validation Accuracy:
# 0.5274
# Epoch 44, CIFAR-10 Batch 1:  loss:
# 1.23244
# Validation Accuracy:
# 0.5396
# Epoch 45, CIFAR-10 Batch 1:  loss:
# 1.20821
# Validation Accuracy:
# 0.5392
# Epoch 46, CIFAR-10 Batch 1:  loss:
# 1.20189
# Validation Accuracy:
# 0.5376
# Epoch 47, CIFAR-10 Batch 1:  loss:
# 1.1966
# Validation Accuracy:
# 0.5478
# Epoch 48, CIFAR-10 Batch 1:  loss:
# 1.17674
# Validation Accuracy:
# 0.5428
# Epoch 49, CIFAR-10 Batch 1:  loss:
# 1.15318
# Validation Accuracy:
# 0.5434
# Epoch 50, CIFAR-10 Batch 1:  loss:
# 1.11684
# Validation Accuracy:
# 0.5544
# Epoch 51, CIFAR-10 Batch 1:  loss:
# 1.14779
# Validation Accuracy:
# 0.5484
# Epoch 52, CIFAR-10 Batch 1:  loss:
# 1.11517
# Validation Accuracy:
# 0.5554
# Epoch 53, CIFAR-10 Batch 1:  loss:
# 1.10918
# Validation Accuracy:
# 0.5554
# Epoch 54, CIFAR-10 Batch 1:  loss:
# 1.09092
# Validation Accuracy:
# 0.5648
# Epoch 55, CIFAR-10 Batch 1:  loss:
# 1.0732
# Validation Accuracy:
# 0.5574
# Epoch 56, CIFAR-10 Batch 1:  loss:
# 1.06848
# Validation Accuracy:
# 0.565
# Epoch 57, CIFAR-10 Batch 1:  loss:
# 1.05503
# Validation Accuracy:
# 0.5662
# Epoch 58, CIFAR-10 Batch 1:  loss:
# 1.04357
# Validation Accuracy:
# 0.569
# Epoch 59, CIFAR-10 Batch 1:  loss:
# 1.0388
# Validation Accuracy:
# 0.5652
# Epoch 60, CIFAR-10 Batch 1:  loss:
# 1.03452
# Validation Accuracy:
# 0.5702
# Epoch 61, CIFAR-10 Batch 1:  loss:
# 1.03274
# Validation Accuracy:
# 0.5686
# Epoch 62, CIFAR-10 Batch 1:  loss:
# 1.02681
# Validation Accuracy:
# 0.5716
# Epoch 63, CIFAR-10 Batch 1:  loss:
# 1.02639
# Validation Accuracy:
# 0.5696
# Epoch 64, CIFAR-10 Batch 1:  loss:
# 0.991136
# Validation Accuracy:
# 0.5672
# Epoch 65, CIFAR-10 Batch 1:  loss:
# 0.993678
# Validation Accuracy:
# 0.5702
# Epoch 66, CIFAR-10 Batch 1:  loss:
# 0.98621
# Validation Accuracy:
# 0.5754
# Epoch 67, CIFAR-10 Batch 1:  loss:
# 0.983312
# Validation Accuracy:
# 0.5702
# Epoch 68, CIFAR-10 Batch 1:  loss:
# 0.959953
# Validation Accuracy:
# 0.5752
# Epoch 69, CIFAR-10 Batch 1:  loss:
# 0.941347
# Validation Accuracy:
# 0.581
# Epoch 70, CIFAR-10 Batch 1:  loss:
# 0.92664
# Validation Accuracy:
# 0.5812
# Epoch 71, CIFAR-10 Batch 1:  loss:
# 0.93505
# Validation Accuracy:
# 0.581
# Epoch 72, CIFAR-10 Batch 1:  loss:
# 0.923705
# Validation Accuracy:
# 0.5812
# Epoch 73, CIFAR-10 Batch 1:  loss:
# 0.932075
# Validation Accuracy:
# 0.5746
# Epoch 74, CIFAR-10 Batch 1:  loss:
# 0.891845
# Validation Accuracy:
# 0.5814
# Epoch 75, CIFAR-10 Batch 1:  loss:
# 0.896875
# Validation Accuracy:
# 0.5828
# Epoch 76, CIFAR-10 Batch 1:  loss:
# 0.910939
# Validation Accuracy:
# 0.586
# Epoch 77, CIFAR-10 Batch 1:  loss:
# 0.863019
# Validation Accuracy:
# 0.586
# Epoch 78, CIFAR-10 Batch 1:  loss:
# 0.889431
# Validation Accuracy:
# 0.5836
# Epoch 79, CIFAR-10 Batch 1:  loss:
# 0.863189
# Validation Accuracy:
# 0.5912
# Epoch 80, CIFAR-10 Batch 1:  loss:
# 0.877658
# Validation Accuracy:
# 0.5852
# Epoch 81, CIFAR-10 Batch 1:  loss:
# 0.843943
# Validation Accuracy:
# 0.589
# Epoch 82, CIFAR-10 Batch 1:  loss:
# 0.828409
# Validation Accuracy:
# 0.5924
# Epoch 83, CIFAR-10 Batch 1:  loss:
# 0.827292
# Validation Accuracy:
# 0.594
# Epoch 84, CIFAR-10 Batch 1:  loss:
# 0.857107
# Validation Accuracy:
# 0.5862
# Epoch 85, CIFAR-10 Batch 1:  loss:
# 0.829054
# Validation Accuracy:
# 0.5922
# Epoch 86, CIFAR-10 Batch 1:  loss:
# 0.808588
# Validation Accuracy:
# 0.5914
# Epoch 87, CIFAR-10 Batch 1:  loss:
# 0.810565
# Validation Accuracy:
# 0.5934
# Epoch 88, CIFAR-10 Batch 1:  loss:
# 0.80974
# Validation Accuracy:
# 0.5942
# Epoch 89, CIFAR-10 Batch 1:  loss:
# 0.789645
# Validation Accuracy:
# 0.5942
# Epoch 90, CIFAR-10 Batch 1:  loss:
# 0.784437
# Validation Accuracy:
# 0.5946
# Epoch 91, CIFAR-10 Batch 1:  loss:
# 0.759194
# Validation Accuracy:
# 0.5952
# Epoch 92, CIFAR-10 Batch 1:  loss:
# 0.772186
# Validation Accuracy:
# 0.597
# Epoch 93, CIFAR-10 Batch 1:  loss:
# 0.754927
# Validation Accuracy:
# 0.6006
# Epoch 94, CIFAR-10 Batch 1:  loss:
# 0.744908
# Validation Accuracy:
# 0.5934
# Epoch 95, CIFAR-10 Batch 1:  loss:
# 0.761922
# Validation Accuracy:
# 0.594
# Epoch 96, CIFAR-10 Batch 1:  loss:
# 0.758148
# Validation Accuracy:
# 0.5966
# Epoch 97, CIFAR-10 Batch 1:  loss:
# 0.735154
# Validation Accuracy:
# 0.5966
# Epoch 98, CIFAR-10 Batch 1:  loss:
# 0.735673
# Validation Accuracy:
# 0.6
# Epoch 99, CIFAR-10 Batch 1:  loss:
# 0.716868
# Validation Accuracy:
# 0.6016
# Epoch 100, CIFAR-10 Batch 1:  loss:
# 0.728836
# Validation Accuracy:
# 0.6032
# Epoch 101, CIFAR-10 Batch 1:  loss:
# 0.724832
# Validation Accuracy:
# 0.6052
# Epoch 102, CIFAR-10 Batch 1:  loss:
# 0.728445
# Validation Accuracy:
# 0.598
# Epoch 103, CIFAR-10 Batch 1:  loss:
# 0.710672
# Validation Accuracy:
# 0.6058
# Epoch 104, CIFAR-10 Batch 1:  loss:
# 0.686091
# Validation Accuracy:
# 0.6056
# Epoch 105, CIFAR-10 Batch 1:  loss:
# 0.674511
# Validation Accuracy:
# 0.603
# Epoch 106, CIFAR-10 Batch 1:  loss:
# 0.689956
# Validation Accuracy:
# 0.6094
# Epoch 107, CIFAR-10 Batch 1:  loss:
# 0.670345
# Validation Accuracy:
# 0.6028
# Epoch 108, CIFAR-10 Batch 1:  loss:
# 0.689676
# Validation Accuracy:
# 0.6086
# Epoch 109, CIFAR-10 Batch 1:  loss:
# 0.657599
# Validation Accuracy:
# 0.6072
# Epoch 110, CIFAR-10 Batch 1:  loss:
# 0.65822
# Validation Accuracy:
# 0.6014
# Epoch 111, CIFAR-10 Batch 1:  loss:
# 0.642969
# Validation Accuracy:
# 0.6086
# Epoch 112, CIFAR-10 Batch 1:  loss:
# 0.64449
# Validation Accuracy:
# 0.6062
# Epoch 113, CIFAR-10 Batch 1:  loss:
# 0.625611
# Validation Accuracy:
# 0.6116
# Epoch 114, CIFAR-10 Batch 1:  loss:
# 0.630163
# Validation Accuracy:
# 0.6062
# Epoch 115, CIFAR-10 Batch 1:  loss:
# 0.633585
# Validation Accuracy:
# 0.6076
# Epoch 116, CIFAR-10 Batch 1:  loss:
# 0.644104
# Validation Accuracy:
# 0.6098
# Epoch 117, CIFAR-10 Batch 1:  loss:
# 0.615019
# Validation Accuracy:
# 0.6108
# Epoch 118, CIFAR-10 Batch 1:  loss:
# 0.605805
# Validation Accuracy:
# 0.6056
# Epoch 119, CIFAR-10 Batch 1:  loss:
# 0.602529
# Validation Accuracy:
# 0.6032
# Epoch 120, CIFAR-10 Batch 1:  loss:
# 0.587428
# Validation Accuracy:
# 0.6132
# Epoch 121, CIFAR-10 Batch 1:  loss:
# 0.621705
# Validation Accuracy:
# 0.6066
# Epoch 122, CIFAR-10 Batch 1:  loss:
# 0.591522
# Validation Accuracy:
# 0.6136
# Epoch 123, CIFAR-10 Batch 1:  loss:
# 0.564369
# Validation Accuracy:
# 0.6194
# Epoch 124, CIFAR-10 Batch 1:  loss:
# 0.577097
# Validation Accuracy:
# 0.61
# Epoch 125, CIFAR-10 Batch 1:  loss:
# 0.565651
# Validation Accuracy:
# 0.6122
# Epoch 126, CIFAR-10 Batch 1:  loss:
# 0.553836
# Validation Accuracy:
# 0.6158
# Epoch 127, CIFAR-10 Batch 1:  loss:
# 0.546756
# Validation Accuracy:
# 0.6152
# Epoch 128, CIFAR-10 Batch 1:  loss:
# 0.543894
# Validation Accuracy:
# 0.614
# Epoch 129, CIFAR-10 Batch 1:  loss:
# 0.56645
# Validation Accuracy:
# 0.61
# Epoch 130, CIFAR-10 Batch 1:  loss:
# 0.549597
# Validation Accuracy:
# 0.6164
# Epoch 131, CIFAR-10 Batch 1:  loss:
# 0.560843
# Validation Accuracy:
# 0.614
# Epoch 132, CIFAR-10 Batch 1:  loss:
# 0.554076
# Validation Accuracy:
# 0.616
# Epoch 133, CIFAR-10 Batch 1:  loss:
# 0.537351
# Validation Accuracy:
# 0.6168
# Epoch 134, CIFAR-10 Batch 1:  loss:
# 0.523498
# Validation Accuracy:
# 0.6162
# Epoch 135, CIFAR-10 Batch 1:  loss:
# 0.546642
# Validation Accuracy:
# 0.617
# Epoch 136, CIFAR-10 Batch 1:  loss:
# 0.506547
# Validation Accuracy:
# 0.621
# Epoch 137, CIFAR-10 Batch 1:  loss:
# 0.507978
# Validation Accuracy:
# 0.6176
# Epoch 138, CIFAR-10 Batch 1:  loss:
# 0.525784
# Validation Accuracy:
# 0.6196
# Epoch 139, CIFAR-10 Batch 1:  loss:
# 0.517625
# Validation Accuracy:
# 0.6198
# Epoch 140, CIFAR-10 Batch 1:  loss:
# 0.504745
# Validation Accuracy:
# 0.6232
# Epoch 141, CIFAR-10 Batch 1:  loss:
# 0.501339
# Validation Accuracy:
# 0.621
# Epoch 142, CIFAR-10 Batch 1:  loss:
# 0.486384
# Validation Accuracy:
# 0.6196
# Epoch 143, CIFAR-10 Batch 1:  loss:
# 0.510475
# Validation Accuracy:
# 0.6244
# Epoch 144, CIFAR-10 Batch 1:  loss:
# 0.498527
# Validation Accuracy:
# 0.6258
# Epoch 145, CIFAR-10 Batch 1:  loss:
# 0.49377
# Validation Accuracy:
# 0.6192
# Epoch 146, CIFAR-10 Batch 1:  loss:
# 0.46097
# Validation Accuracy:
# 0.6226
# Epoch 147, CIFAR-10 Batch 1:  loss:
# 0.463756
# Validation Accuracy:
# 0.6244
# Epoch 148, CIFAR-10 Batch 1:  loss:
# 0.450445
# Validation Accuracy:
# 0.624
# Epoch 149, CIFAR-10 Batch 1:  loss:
# 0.448524
# Validation Accuracy:
# 0.6222
# Epoch 150, CIFAR-10 Batch 1:  loss:
# 0.454134
# Validation Accuracy:
# 0.622

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss:
# 2.30268
# Validation Accuracy:
# 0.102
# Epoch  1, CIFAR-10 Batch 2:  loss:
# 2.30287
# Validation Accuracy:
# 0.102
# Epoch  1, CIFAR-10 Batch 3:  loss:
# 2.30263
# Validation Accuracy:
# 0.102
# Epoch  1, CIFAR-10 Batch 4:  loss:
# 2.30247
# Validation Accuracy:
# 0.0942
# Epoch  1, CIFAR-10 Batch 5:  loss:
# 2.30257
# Validation Accuracy:
# 0.0942
# Epoch  2, CIFAR-10 Batch 1:  loss:
# 2.30271
# Validation Accuracy:
# 0.0946
# Epoch  2, CIFAR-10 Batch 2:  loss:
# 2.30261
# Validation Accuracy:
# 0.0946
# Epoch  2, CIFAR-10 Batch 3:  loss:
# 2.30249
# Validation Accuracy:
# 0.0942
# Epoch  2, CIFAR-10 Batch 4:  loss:
# 2.30251
# Validation Accuracy:
# 0.0942
# Epoch  2, CIFAR-10 Batch 5:  loss:
# 2.30254
# Validation Accuracy:
# 0.095
# Epoch  3, CIFAR-10 Batch 1:  loss:
# 2.30284
# Validation Accuracy:
# 0.0956
# Epoch  3, CIFAR-10 Batch 2:  loss:
# 2.29121
# Validation Accuracy:
# 0.138
# Epoch  3, CIFAR-10 Batch 3:  loss:
# 2.26647
# Validation Accuracy:
# 0.143
# Epoch  3, CIFAR-10 Batch 4:  loss:
# 2.20572
# Validation Accuracy:
# 0.1626
# Epoch  3, CIFAR-10 Batch 5:  loss:
# 2.15724
# Validation Accuracy:
# 0.1828
# Epoch  4, CIFAR-10 Batch 1:  loss:
# 2.21563
# Validation Accuracy:
# 0.1736
# Epoch  4, CIFAR-10 Batch 2:  loss:
# 2.1139
# Validation Accuracy:
# 0.2222
# Epoch  4, CIFAR-10 Batch 3:  loss:
# 2.05859
# Validation Accuracy:
# 0.243
# Epoch  4, CIFAR-10 Batch 4:  loss:
# 1.96606
# Validation Accuracy:
# 0.2672
# Epoch  4, CIFAR-10 Batch 5:  loss:
# 1.96353
# Validation Accuracy:
# 0.2972
# Epoch  5, CIFAR-10 Batch 1:  loss:
# 1.98837
# Validation Accuracy:
# 0.311
# Epoch  5, CIFAR-10 Batch 2:  loss:
# 1.87975
# Validation Accuracy:
# 0.313
# Epoch  5, CIFAR-10 Batch 3:  loss:
# 1.82161
# Validation Accuracy:
# 0.2866
# Epoch  5, CIFAR-10 Batch 4:  loss:
# 1.80829
# Validation Accuracy:
# 0.3028
# Epoch  5, CIFAR-10 Batch 5:  loss:
# 1.83795
# Validation Accuracy:
# 0.2988
# Epoch  6, CIFAR-10 Batch 1:  loss:
# 1.85919
# Validation Accuracy:
# 0.3546
# Epoch  6, CIFAR-10 Batch 2:  loss:
# 1.86675
# Validation Accuracy:
# 0.321
# Epoch  6, CIFAR-10 Batch 3:  loss:
# 1.75343
# Validation Accuracy:
# 0.3506
# Epoch  6, CIFAR-10 Batch 4:  loss:
# 1.72886
# Validation Accuracy:
# 0.3616
# Epoch  6, CIFAR-10 Batch 5:  loss:
# 1.80281
# Validation Accuracy:
# 0.3494
# Epoch  7, CIFAR-10 Batch 1:  loss:
# 1.81913
# Validation Accuracy:
# 0.373
# Epoch  7, CIFAR-10 Batch 2:  loss:
# 1.74133
# Validation Accuracy:
# 0.3766
# Epoch  7, CIFAR-10 Batch 3:  loss:
# 1.65749
# Validation Accuracy:
# 0.3792
# Epoch  7, CIFAR-10 Batch 4:  loss:
# 1.65058
# Validation Accuracy:
# 0.4044
# Epoch  7, CIFAR-10 Batch 5:  loss:
# 1.69405
# Validation Accuracy:
# 0.3994
# Epoch  8, CIFAR-10 Batch 1:  loss:
# 1.7259
# Validation Accuracy:
# 0.4208
# Epoch  8, CIFAR-10 Batch 2:  loss:
# 1.65437
# Validation Accuracy:
# 0.421
# Epoch  8, CIFAR-10 Batch 3:  loss:
# 1.57161
# Validation Accuracy:
# 0.4182
# Epoch  8, CIFAR-10 Batch 4:  loss:
# 1.5691
# Validation Accuracy:
# 0.4358
# Epoch  8, CIFAR-10 Batch 5:  loss:
# 1.64531
# Validation Accuracy:
# 0.4314
# Epoch  9, CIFAR-10 Batch 1:  loss:
# 1.65488
# Validation Accuracy:
# 0.4362
# Epoch  9, CIFAR-10 Batch 2:  loss:
# 1.5821
# Validation Accuracy:
# 0.43
# Epoch  9, CIFAR-10 Batch 3:  loss:
# 1.49529
# Validation Accuracy:
# 0.4378
# Epoch  9, CIFAR-10 Batch 4:  loss:
# 1.49007
# Validation Accuracy:
# 0.4626
# Epoch  9, CIFAR-10 Batch 5:  loss:
# 1.55107
# Validation Accuracy:
# 0.4622
# Epoch 10, CIFAR-10 Batch 1:  loss:
# 1.58313
# Validation Accuracy:
# 0.4746
# Epoch 10, CIFAR-10 Batch 2:  loss:
# 1.52004
# Validation Accuracy:
# 0.473
# Epoch 10, CIFAR-10 Batch 3:  loss:
# 1.40638
# Validation Accuracy:
# 0.4674
# Epoch 10, CIFAR-10 Batch 4:  loss:
# 1.43558
# Validation Accuracy:
# 0.4764
# Epoch 10, CIFAR-10 Batch 5:  loss:
# 1.51829
# Validation Accuracy:
# 0.4802
# Epoch 11, CIFAR-10 Batch 1:  loss:
# 1.50847
# Validation Accuracy:
# 0.4932
# Epoch 11, CIFAR-10 Batch 2:  loss:
# 1.46329
# Validation Accuracy:
# 0.4924
# Epoch 11, CIFAR-10 Batch 3:  loss:
# 1.35235
# Validation Accuracy:
# 0.4886
# Epoch 11, CIFAR-10 Batch 4:  loss:
# 1.35255
# Validation Accuracy:
# 0.4984
# Epoch 11, CIFAR-10 Batch 5:  loss:
# 1.45642
# Validation Accuracy:
# 0.494
# Epoch 12, CIFAR-10 Batch 1:  loss:
# 1.45453
# Validation Accuracy:
# 0.5114
# Epoch 12, CIFAR-10 Batch 2:  loss:
# 1.39037
# Validation Accuracy:
# 0.5092
# Epoch 12, CIFAR-10 Batch 3:  loss:
# 1.2857
# Validation Accuracy:
# 0.5018
# Epoch 12, CIFAR-10 Batch 4:  loss:
# 1.3038
# Validation Accuracy:
# 0.5096
# Epoch 12, CIFAR-10 Batch 5:  loss:
# 1.37638
# Validation Accuracy:
# 0.5124
# Epoch 13, CIFAR-10 Batch 1:  loss:
# 1.41569
# Validation Accuracy:
# 0.5234
# Epoch 13, CIFAR-10 Batch 2:  loss:
# 1.35904
# Validation Accuracy:
# 0.5214
# Epoch 13, CIFAR-10 Batch 3:  loss:
# 1.25301
# Validation Accuracy:
# 0.5282
# Epoch 13, CIFAR-10 Batch 4:  loss:
# 1.27495
# Validation Accuracy:
# 0.5328
# Epoch 13, CIFAR-10 Batch 5:  loss:
# 1.32613
# Validation Accuracy:
# 0.5284
# Epoch 14, CIFAR-10 Batch 1:  loss:
# 1.37725
# Validation Accuracy:
# 0.5392
# Epoch 14, CIFAR-10 Batch 2:  loss:
# 1.32564
# Validation Accuracy:
# 0.5342
# Epoch 14, CIFAR-10 Batch 3:  loss:
# 1.21933
# Validation Accuracy:
# 0.5396
# Epoch 14, CIFAR-10 Batch 4:  loss:
# 1.23623
# Validation Accuracy:
# 0.5342
# Epoch 14, CIFAR-10 Batch 5:  loss:
# 1.31249
# Validation Accuracy:
# 0.5264
# Epoch 15, CIFAR-10 Batch 1:  loss:
# 1.35852
# Validation Accuracy:
# 0.541
# Epoch 15, CIFAR-10 Batch 2:  loss:
# 1.2697
# Validation Accuracy:
# 0.5542
# Epoch 15, CIFAR-10 Batch 3:  loss:
# 1.19333
# Validation Accuracy:
# 0.5518
# Epoch 15, CIFAR-10 Batch 4:  loss:
# 1.21934
# Validation Accuracy:
# 0.5442
# Epoch 15, CIFAR-10 Batch 5:  loss:
# 1.26131
# Validation Accuracy:
# 0.552
# Epoch 16, CIFAR-10 Batch 1:  loss:
# 1.30514
# Validation Accuracy:
# 0.5654
# Epoch 16, CIFAR-10 Batch 2:  loss:
# 1.24387
# Validation Accuracy:
# 0.5588
# Epoch 16, CIFAR-10 Batch 3:  loss:
# 1.17075
# Validation Accuracy:
# 0.5476
# Epoch 16, CIFAR-10 Batch 4:  loss:
# 1.1856
# Validation Accuracy:
# 0.5574
# Epoch 16, CIFAR-10 Batch 5:  loss:
# 1.23833
# Validation Accuracy:
# 0.5562
# Epoch 17, CIFAR-10 Batch 1:  loss:
# 1.30505
# Validation Accuracy:
# 0.5706
# Epoch 17, CIFAR-10 Batch 2:  loss:
# 1.21782
# Validation Accuracy:
# 0.5566
# Epoch 17, CIFAR-10 Batch 3:  loss:
# 1.11728
# Validation Accuracy:
# 0.5714
# Epoch 17, CIFAR-10 Batch 4:  loss:
# 1.14207
# Validation Accuracy:
# 0.5668
# Epoch 17, CIFAR-10 Batch 5:  loss:
# 1.21166
# Validation Accuracy:
# 0.5756
# Epoch 18, CIFAR-10 Batch 1:  loss:
# 1.28635
# Validation Accuracy:
# 0.5778
# Epoch 18, CIFAR-10 Batch 2:  loss:
# 1.19915
# Validation Accuracy:
# 0.5752
# Epoch 18, CIFAR-10 Batch 3:  loss:
# 1.09873
# Validation Accuracy:
# 0.5738
# Epoch 18, CIFAR-10 Batch 4:  loss:
# 1.11142
# Validation Accuracy:
# 0.5756
# Epoch 18, CIFAR-10 Batch 5:  loss:
# 1.17619
# Validation Accuracy:
# 0.5726
# Epoch 19, CIFAR-10 Batch 1:  loss:
# 1.24571
# Validation Accuracy:
# 0.5842
# Epoch 19, CIFAR-10 Batch 2:  loss:
# 1.15738
# Validation Accuracy:
# 0.581
# Epoch 19, CIFAR-10 Batch 3:  loss:
# 1.12865
# Validation Accuracy:
# 0.5574
# Epoch 19, CIFAR-10 Batch 4:  loss:
# 1.08675
# Validation Accuracy:
# 0.5806
# Epoch 19, CIFAR-10 Batch 5:  loss:
# 1.16245
# Validation Accuracy:
# 0.5802
# Epoch 20, CIFAR-10 Batch 1:  loss:
# 1.21669
# Validation Accuracy:
# 0.5836
# Epoch 20, CIFAR-10 Batch 2:  loss:
# 1.11544
# Validation Accuracy:
# 0.5912
# Epoch 20, CIFAR-10 Batch 3:  loss:
# 1.07127
# Validation Accuracy:
# 0.5876
# Epoch 20, CIFAR-10 Batch 4:  loss:
# 1.0586
# Validation Accuracy:
# 0.5866
# Epoch 20, CIFAR-10 Batch 5:  loss:
# 1.14604
# Validation Accuracy:
# 0.5844
# Epoch 21, CIFAR-10 Batch 1:  loss:
# 1.20003
# Validation Accuracy:
# 0.6004
# Epoch 21, CIFAR-10 Batch 2:  loss:
# 1.10292
# Validation Accuracy:
# 0.5952
# Epoch 21, CIFAR-10 Batch 3:  loss:
# 1.04832
# Validation Accuracy:
# 0.5822
# Epoch 21, CIFAR-10 Batch 4:  loss:
# 1.06268
# Validation Accuracy:
# 0.596
# Epoch 21, CIFAR-10 Batch 5:  loss:
# 1.11946
# Validation Accuracy:
# 0.5882
# Epoch 22, CIFAR-10 Batch 1:  loss:
# 1.17841
# Validation Accuracy:
# 0.5988
# Epoch 22, CIFAR-10 Batch 2:  loss:
# 1.07403
# Validation Accuracy:
# 0.5948
# Epoch 22, CIFAR-10 Batch 3:  loss:
# 1.02669
# Validation Accuracy:
# 0.5984
# Epoch 22, CIFAR-10 Batch 4:  loss:
# 1.04457
# Validation Accuracy:
# 0.5918
# Epoch 22, CIFAR-10 Batch 5:  loss:
# 1.10515
# Validation Accuracy:
# 0.5962
# Epoch 23, CIFAR-10 Batch 1:  loss:
# 1.1693
# Validation Accuracy:
# 0.6024
# Epoch 23, CIFAR-10 Batch 2:  loss:
# 1.09694
# Validation Accuracy:
# 0.5868
# Epoch 23, CIFAR-10 Batch 3:  loss:
# 1.02657
# Validation Accuracy:
# 0.5962
# Epoch 23, CIFAR-10 Batch 4:  loss:
# 1.02462
# Validation Accuracy:
# 0.5976
# Epoch 23, CIFAR-10 Batch 5:  loss:
# 1.07463
# Validation Accuracy:
# 0.6036
# Epoch 24, CIFAR-10 Batch 1:  loss:
# 1.14634
# Validation Accuracy:
# 0.6058
# Epoch 24, CIFAR-10 Batch 2:  loss:
# 1.05797
# Validation Accuracy:
# 0.6126
# Epoch 24, CIFAR-10 Batch 3:  loss:
# 1.01354
# Validation Accuracy:
# 0.6054
# Epoch 24, CIFAR-10 Batch 4:  loss:
# 1.01532
# Validation Accuracy:
# 0.6092
# Epoch 24, CIFAR-10 Batch 5:  loss:
# 1.07834
# Validation Accuracy:
# 0.6032
# Epoch 25, CIFAR-10 Batch 1:  loss:
# 1.12365
# Validation Accuracy:
# 0.6154
# Epoch 25, CIFAR-10 Batch 2:  loss:
# 1.04185
# Validation Accuracy:
# 0.6122
# Epoch 25, CIFAR-10 Batch 3:  loss:
# 0.987788
# Validation Accuracy:
# 0.609
# Epoch 25, CIFAR-10 Batch 4:  loss:
# 0.958305
# Validation Accuracy:
# 0.6184
# Epoch 25, CIFAR-10 Batch 5:  loss:
# 1.07755
# Validation Accuracy:
# 0.6064
# Epoch 26, CIFAR-10 Batch 1:  loss:
# 1.10956
# Validation Accuracy:
# 0.615
# Epoch 26, CIFAR-10 Batch 2:  loss:
# 1.02008
# Validation Accuracy:
# 0.6128
# Epoch 26, CIFAR-10 Batch 3:  loss:
# 0.97772
# Validation Accuracy:
# 0.612
# Epoch 26, CIFAR-10 Batch 4:  loss:
# 0.955394
# Validation Accuracy:
# 0.6142
# Epoch 26, CIFAR-10 Batch 5:  loss:
# 1.04415
# Validation Accuracy:
# 0.613
# Epoch 27, CIFAR-10 Batch 1:  loss:
# 1.10758
# Validation Accuracy:
# 0.6194
# Epoch 27, CIFAR-10 Batch 2:  loss:
# 1.01327
# Validation Accuracy:
# 0.6192
# Epoch 27, CIFAR-10 Batch 3:  loss:
# 0.964712
# Validation Accuracy:
# 0.614
# Epoch 27, CIFAR-10 Batch 4:  loss:
# 0.975707
# Validation Accuracy:
# 0.6124
# Epoch 27, CIFAR-10 Batch 5:  loss:
# 1.00184
# Validation Accuracy:
# 0.611
# Epoch 28, CIFAR-10 Batch 1:  loss:
# 1.09651
# Validation Accuracy:
# 0.6212
# Epoch 28, CIFAR-10 Batch 2:  loss:
# 0.998288
# Validation Accuracy:
# 0.62
# Epoch 28, CIFAR-10 Batch 3:  loss:
# 0.943759
# Validation Accuracy:
# 0.6164
# Epoch 28, CIFAR-10 Batch 4:  loss:
# 0.938186
# Validation Accuracy:
# 0.625
# Epoch 28, CIFAR-10 Batch 5:  loss:
# 0.980019
# Validation Accuracy:
# 0.6244
# Epoch 29, CIFAR-10 Batch 1:  loss:
# 1.06573
# Validation Accuracy:
# 0.6258
# Epoch 29, CIFAR-10 Batch 2:  loss:
# 0.995664
# Validation Accuracy:
# 0.6232
# Epoch 29, CIFAR-10 Batch 3:  loss:
# 0.911819
# Validation Accuracy:
# 0.6208
# Epoch 29, CIFAR-10 Batch 4:  loss:
# 0.921071
# Validation Accuracy:
# 0.6222
# Epoch 29, CIFAR-10 Batch 5:  loss:
# 0.983069
# Validation Accuracy:
# 0.6162
# Epoch 30, CIFAR-10 Batch 1:  loss:
# 1.07578
# Validation Accuracy:
# 0.627
# Epoch 30, CIFAR-10 Batch 2:  loss:
# 0.986359
# Validation Accuracy:
# 0.6234
# Epoch 30, CIFAR-10 Batch 3:  loss:
# 0.944591
# Validation Accuracy:
# 0.6248
# Epoch 30, CIFAR-10 Batch 4:  loss:
# 0.916836
# Validation Accuracy:
# 0.6308
# Epoch 30, CIFAR-10 Batch 5:  loss:
# 0.986339
# Validation Accuracy:
# 0.6204
# Epoch 31, CIFAR-10 Batch 1:  loss:
# 1.03036
# Validation Accuracy:
# 0.6288
# Epoch 31, CIFAR-10 Batch 2:  loss:
# 0.989198
# Validation Accuracy:
# 0.6334
# Epoch 31, CIFAR-10 Batch 3:  loss:
# 0.907903
# Validation Accuracy:
# 0.6246
# Epoch 31, CIFAR-10 Batch 4:  loss:
# 0.90071
# Validation Accuracy:
# 0.6382
# Epoch 31, CIFAR-10 Batch 5:  loss:
# 0.962831
# Validation Accuracy:
# 0.6302
# Epoch 32, CIFAR-10 Batch 1:  loss:
# 1.04648
# Validation Accuracy:
# 0.631
# Epoch 32, CIFAR-10 Batch 2:  loss:
# 0.981328
# Validation Accuracy:
# 0.6246
# Epoch 32, CIFAR-10 Batch 3:  loss:
# 0.902437
# Validation Accuracy:
# 0.6248
# Epoch 32, CIFAR-10 Batch 4:  loss:
# 0.895344
# Validation Accuracy:
# 0.6314
# Epoch 32, CIFAR-10 Batch 5:  loss:
# 0.950516
# Validation Accuracy:
# 0.6292
# Epoch 33, CIFAR-10 Batch 1:  loss:
# 1.03013
# Validation Accuracy:
# 0.6364
# Epoch 33, CIFAR-10 Batch 2:  loss:
# 1.00238
# Validation Accuracy:
# 0.6242
# Epoch 33, CIFAR-10 Batch 3:  loss:
# 0.900326
# Validation Accuracy:
# 0.6324
# Epoch 33, CIFAR-10 Batch 4:  loss:
# 0.899258
# Validation Accuracy:
# 0.6328
# Epoch 33, CIFAR-10 Batch 5:  loss:
# 0.93495
# Validation Accuracy:
# 0.6328
# Epoch 34, CIFAR-10 Batch 1:  loss:
# 1.03657
# Validation Accuracy:
# 0.6318
# Epoch 34, CIFAR-10 Batch 2:  loss:
# 0.964604
# Validation Accuracy:
# 0.637
# Epoch 34, CIFAR-10 Batch 3:  loss:
# 0.855792
# Validation Accuracy:
# 0.6374
# Epoch 34, CIFAR-10 Batch 4:  loss:
# 0.887956
# Validation Accuracy:
# 0.64
# Epoch 34, CIFAR-10 Batch 5:  loss:
# 0.927781
# Validation Accuracy:
# 0.6348
# Epoch 35, CIFAR-10 Batch 1:  loss:
# 1.02681
# Validation Accuracy:
# 0.64
# Epoch 35, CIFAR-10 Batch 2:  loss:
# 0.945331
# Validation Accuracy:
# 0.6378
# Epoch 35, CIFAR-10 Batch 3:  loss:
# 0.855012
# Validation Accuracy:
# 0.638
# Epoch 35, CIFAR-10 Batch 4:  loss:
# 0.868612
# Validation Accuracy:
# 0.6418
# Epoch 35, CIFAR-10 Batch 5:  loss:
# 0.924408
# Validation Accuracy:
# 0.6336
# Epoch 36, CIFAR-10 Batch 1:  loss:
# 1.01143
# Validation Accuracy:
# 0.6342
# Epoch 36, CIFAR-10 Batch 2:  loss:
# 0.915937
# Validation Accuracy:
# 0.6452
# Epoch 36, CIFAR-10 Batch 3:  loss:
# 0.849543
# Validation Accuracy:
# 0.6418
# Epoch 36, CIFAR-10 Batch 4:  loss:
# 0.850675
# Validation Accuracy:
# 0.6416
# Epoch 36, CIFAR-10 Batch 5:  loss:
# 0.893529
# Validation Accuracy:
# 0.638
# Epoch 37, CIFAR-10 Batch 1:  loss:
# 1.00458
# Validation Accuracy:
# 0.6384
# Epoch 37, CIFAR-10 Batch 2:  loss:
# 0.93564
# Validation Accuracy:
# 0.6436
# Epoch 37, CIFAR-10 Batch 3:  loss:
# 0.842451
# Validation Accuracy:
# 0.6436
# Epoch 37, CIFAR-10 Batch 4:  loss:
# 0.854741
# Validation Accuracy:
# 0.6422
# Epoch 37, CIFAR-10 Batch 5:  loss:
# 0.903914
# Validation Accuracy:
# 0.6438
# Epoch 38, CIFAR-10 Batch 1:  loss:
# 0.977478
# Validation Accuracy:
# 0.644
# Epoch 38, CIFAR-10 Batch 2:  loss:
# 0.912762
# Validation Accuracy:
# 0.6422
# Epoch 38, CIFAR-10 Batch 3:  loss:
# 0.838027
# Validation Accuracy:
# 0.6376
# Epoch 38, CIFAR-10 Batch 4:  loss:
# 0.844265
# Validation Accuracy:
# 0.6472
# Epoch 38, CIFAR-10 Batch 5:  loss:
# 0.898393
# Validation Accuracy:
# 0.6462
# Epoch 39, CIFAR-10 Batch 1:  loss:
# 0.97527
# Validation Accuracy:
# 0.6438
# Epoch 39, CIFAR-10 Batch 2:  loss:
# 0.910203
# Validation Accuracy:
# 0.648
# Epoch 39, CIFAR-10 Batch 3:  loss:
# 0.834929
# Validation Accuracy:
# 0.6438
# Epoch 39, CIFAR-10 Batch 4:  loss:
# 0.839268
# Validation Accuracy:
# 0.6424
# Epoch 39, CIFAR-10 Batch 5:  loss:
# 0.903727
# Validation Accuracy:
# 0.644
# Epoch 40, CIFAR-10 Batch 1:  loss:
# 0.972061
# Validation Accuracy:
# 0.6438
# Epoch 40, CIFAR-10 Batch 2:  loss:
# 0.888942
# Validation Accuracy:
# 0.6484
# Epoch 40, CIFAR-10 Batch 3:  loss:
# 0.830308
# Validation Accuracy:
# 0.6442
# Epoch 40, CIFAR-10 Batch 4:  loss:
# 0.856912
# Validation Accuracy:
# 0.645
# Epoch 40, CIFAR-10 Batch 5:  loss:
# 0.877813
# Validation Accuracy:
# 0.6452
# Epoch 41, CIFAR-10 Batch 1:  loss:
# 0.974722
# Validation Accuracy:
# 0.6442
# Epoch 41, CIFAR-10 Batch 2:  loss:
# 0.898872
# Validation Accuracy:
# 0.6522
# Epoch 41, CIFAR-10 Batch 3:  loss:
# 0.814446
# Validation Accuracy:
# 0.6458
# Epoch 41, CIFAR-10 Batch 4:  loss:
# 0.834279
# Validation Accuracy:
# 0.6562
# Epoch 41, CIFAR-10 Batch 5:  loss:
# 0.869813
# Validation Accuracy:
# 0.6502
# Epoch 42, CIFAR-10 Batch 1:  loss:
# 0.967972
# Validation Accuracy:
# 0.6446
# Epoch 42, CIFAR-10 Batch 2:  loss:
# 0.913005
# Validation Accuracy:
# 0.6428
# Epoch 42, CIFAR-10 Batch 3:  loss:
# 0.81795
# Validation Accuracy:
# 0.6458
# Epoch 42, CIFAR-10 Batch 4:  loss:
# 0.82501
# Validation Accuracy:
# 0.6498
# Epoch 42, CIFAR-10 Batch 5:  loss:
# 0.876956
# Validation Accuracy:
# 0.6464
# Epoch 43, CIFAR-10 Batch 1:  loss:
# 0.950703
# Validation Accuracy:
# 0.6426
# Epoch 43, CIFAR-10 Batch 2:  loss:
# 0.871727
# Validation Accuracy:
# 0.6482
# Epoch 43, CIFAR-10 Batch 3:  loss:
# 0.806468
# Validation Accuracy:
# 0.6506
# Epoch 43, CIFAR-10 Batch 4:  loss:
# 0.7934
# Validation Accuracy:
# 0.658
# Epoch 43, CIFAR-10 Batch 5:  loss:
# 0.85751
# Validation Accuracy:
# 0.647
# Epoch 44, CIFAR-10 Batch 1:  loss:
# 0.948323
# Validation Accuracy:
# 0.6476
# Epoch 44, CIFAR-10 Batch 2:  loss:
# 0.863525
# Validation Accuracy:
# 0.6596
# Epoch 44, CIFAR-10 Batch 3:  loss:
# 0.799527
# Validation Accuracy:
# 0.6542
# Epoch 44, CIFAR-10 Batch 4:  loss:
# 0.801516
# Validation Accuracy:
# 0.6608
# Epoch 44, CIFAR-10 Batch 5:  loss:
# 0.838875
# Validation Accuracy:
# 0.6528
# Epoch 45, CIFAR-10 Batch 1:  loss:
# 0.935539
# Validation Accuracy:
# 0.6556
# Epoch 45, CIFAR-10 Batch 2:  loss:
# 0.846653
# Validation Accuracy:
# 0.6568
# Epoch 45, CIFAR-10 Batch 3:  loss:
# 0.769953
# Validation Accuracy:
# 0.6552
# Epoch 45, CIFAR-10 Batch 4:  loss:
# 0.839075
# Validation Accuracy:
# 0.6462
# Epoch 45, CIFAR-10 Batch 5:  loss:
# 0.882035
# Validation Accuracy:
# 0.649
# Epoch 46, CIFAR-10 Batch 1:  loss:
# 0.948245
# Validation Accuracy:
# 0.6458
# Epoch 46, CIFAR-10 Batch 2:  loss:
# 0.863759
# Validation Accuracy:
# 0.6496
# Epoch 46, CIFAR-10 Batch 3:  loss:
# 0.799816
# Validation Accuracy:
# 0.6498
# Epoch 46, CIFAR-10 Batch 4:  loss:
# 0.787694
# Validation Accuracy:
# 0.6544
# Epoch 46, CIFAR-10 Batch 5:  loss:
# 0.829135
# Validation Accuracy:
# 0.6574
# Epoch 47, CIFAR-10 Batch 1:  loss:
# 0.913934
# Validation Accuracy:
# 0.6572
# Epoch 47, CIFAR-10 Batch 2:  loss:
# 0.85352
# Validation Accuracy:
# 0.6548
# Epoch 47, CIFAR-10 Batch 3:  loss:
# 0.777801
# Validation Accuracy:
# 0.6538
# Epoch 47, CIFAR-10 Batch 4:  loss:
# 0.777308
# Validation Accuracy:
# 0.6602
# Epoch 47, CIFAR-10 Batch 5:  loss:
# 0.821305
# Validation Accuracy:
# 0.6578
# Epoch 48, CIFAR-10 Batch 1:  loss:
# 0.922011
# Validation Accuracy:
# 0.6586
# Epoch 48, CIFAR-10 Batch 2:  loss:
# 0.853738
# Validation Accuracy:
# 0.6514
# Epoch 48, CIFAR-10 Batch 3:  loss:
# 0.768204
# Validation Accuracy:
# 0.655
# Epoch 48, CIFAR-10 Batch 4:  loss:
# 0.767245
# Validation Accuracy:
# 0.6636
# Epoch 48, CIFAR-10 Batch 5:  loss:
# 0.819645
# Validation Accuracy:
# 0.654
# Epoch 49, CIFAR-10 Batch 1:  loss:
# 0.90809
# Validation Accuracy:
# 0.6608
# Epoch 49, CIFAR-10 Batch 2:  loss:
# 0.835499
# Validation Accuracy:
# 0.6544
# Epoch 49, CIFAR-10 Batch 3:  loss:
# 0.770491
# Validation Accuracy:
# 0.6542
# Epoch 49, CIFAR-10 Batch 4:  loss:
# 0.774702
# Validation Accuracy:
# 0.659
# Epoch 49, CIFAR-10 Batch 5:  loss:
# 0.840706
# Validation Accuracy:
# 0.659
# Epoch 50, CIFAR-10 Batch 1:  loss:
# 0.884601
# Validation Accuracy:
# 0.6606
# Epoch 50, CIFAR-10 Batch 2:  loss:
# 0.835048
# Validation Accuracy:
# 0.6624
# Epoch 50, CIFAR-10 Batch 3:  loss:
# 0.786331
# Validation Accuracy:
# 0.6548
# Epoch 50, CIFAR-10 Batch 4:  loss:
# 0.769538
# Validation Accuracy:
# 0.661
# Epoch 50, CIFAR-10 Batch 5:  loss:
# 0.832437
# Validation Accuracy:
# 0.6526
# Epoch 51, CIFAR-10 Batch 1:  loss:
# 0.917826
# Validation Accuracy:
# 0.6536
# Epoch 51, CIFAR-10 Batch 2:  loss:
# 0.829113
# Validation Accuracy:
# 0.6606
# Epoch 51, CIFAR-10 Batch 3:  loss:
# 0.759619
# Validation Accuracy:
# 0.6538
# Epoch 51, CIFAR-10 Batch 4:  loss:
# 0.764537
# Validation Accuracy:
# 0.6638
# Epoch 51, CIFAR-10 Batch 5:  loss:
# 0.814909
# Validation Accuracy:
# 0.662
# Epoch 52, CIFAR-10 Batch 1:  loss:
# 0.88408
# Validation Accuracy:
# 0.667
# Epoch 52, CIFAR-10 Batch 2:  loss:
# 0.824979
# Validation Accuracy:
# 0.6582
# Epoch 52, CIFAR-10 Batch 3:  loss:
# 0.750034
# Validation Accuracy:
# 0.6584
# Epoch 52, CIFAR-10 Batch 4:  loss:
# 0.758525
# Validation Accuracy:
# 0.6644
# Epoch 52, CIFAR-10 Batch 5:  loss:
# 0.82336
# Validation Accuracy:
# 0.6572
# Epoch 53, CIFAR-10 Batch 1:  loss:
# 0.883786
# Validation Accuracy:
# 0.6542
# Epoch 53, CIFAR-10 Batch 2:  loss:
# 0.803346
# Validation Accuracy:
# 0.6644
# Epoch 53, CIFAR-10 Batch 3:  loss:
# 0.746902
# Validation Accuracy:
# 0.6666
# Epoch 53, CIFAR-10 Batch 4:  loss:
# 0.754643
# Validation Accuracy:
# 0.6564
# Epoch 53, CIFAR-10 Batch 5:  loss:
# 0.808338
# Validation Accuracy:
# 0.6642
# Epoch 54, CIFAR-10 Batch 1:  loss:
# 0.876606
# Validation Accuracy:
# 0.6638
# Epoch 54, CIFAR-10 Batch 2:  loss:
# 0.81791
# Validation Accuracy:
# 0.6582
# Epoch 54, CIFAR-10 Batch 3:  loss:
# 0.75074
# Validation Accuracy:
# 0.6612
# Epoch 54, CIFAR-10 Batch 4:  loss:
# 0.754629
# Validation Accuracy:
# 0.6686
# Epoch 54, CIFAR-10 Batch 5:  loss:
# 0.79467
# Validation Accuracy:
# 0.6588
# Epoch 55, CIFAR-10 Batch 1:  loss:
# 0.894159
# Validation Accuracy:
# 0.6614
# Epoch 55, CIFAR-10 Batch 2:  loss:
# 0.795458
# Validation Accuracy:
# 0.6602
# Epoch 55, CIFAR-10 Batch 3:  loss:
# 0.738224
# Validation Accuracy:
# 0.6624
# Epoch 55, CIFAR-10 Batch 4:  loss:
# 0.7538
# Validation Accuracy:
# 0.6596
# Epoch 55, CIFAR-10 Batch 5:  loss:
# 0.802358
# Validation Accuracy:
# 0.6596
# Epoch 56, CIFAR-10 Batch 1:  loss:
# 0.872467
# Validation Accuracy:
# 0.6654
# Epoch 56, CIFAR-10 Batch 2:  loss:
# 0.805467
# Validation Accuracy:
# 0.6654
# Epoch 56, CIFAR-10 Batch 3:  loss:
# 0.736567
# Validation Accuracy:
# 0.6676
# Epoch 56, CIFAR-10 Batch 4:  loss:
# 0.737042
# Validation Accuracy:
# 0.663
# Epoch 56, CIFAR-10 Batch 5:  loss:
# 0.803052
# Validation Accuracy:
# 0.6556
# Epoch 57, CIFAR-10 Batch 1:  loss:
# 0.85069
# Validation Accuracy:
# 0.6646
# Epoch 57, CIFAR-10 Batch 2:  loss:
# 0.78384
# Validation Accuracy:
# 0.6686
# Epoch 57, CIFAR-10 Batch 3:  loss:
# 0.732479
# Validation Accuracy:
# 0.6682
# Epoch 57, CIFAR-10 Batch 4:  loss:
# 0.735105
# Validation Accuracy:
# 0.6626
# Epoch 57, CIFAR-10 Batch 5:  loss:
# 0.778835
# Validation Accuracy:
# 0.6656
# Epoch 58, CIFAR-10 Batch 1:  loss:
# 0.869752
# Validation Accuracy:
# 0.6626
# Epoch 58, CIFAR-10 Batch 2:  loss:
# 0.768761
# Validation Accuracy:
# 0.6676
# Epoch 58, CIFAR-10 Batch 3:  loss:
# 0.711434
# Validation Accuracy:
# 0.6692
# Epoch 58, CIFAR-10 Batch 4:  loss:
# 0.741046
# Validation Accuracy:
# 0.6646
# Epoch 58, CIFAR-10 Batch 5:  loss:
# 0.773043
# Validation Accuracy:
# 0.6656
# Epoch 59, CIFAR-10 Batch 1:  loss:
# 0.863091
# Validation Accuracy:
# 0.6574
# Epoch 59, CIFAR-10 Batch 2:  loss:
# 0.763492
# Validation Accuracy:
# 0.6752
# Epoch 59, CIFAR-10 Batch 3:  loss:
# 0.735805
# Validation Accuracy:
# 0.6592
# Epoch 59, CIFAR-10 Batch 4:  loss:
# 0.751502
# Validation Accuracy:
# 0.6618
# Epoch 59, CIFAR-10 Batch 5:  loss:
# 0.769178
# Validation Accuracy:
# 0.6606
# Epoch 60, CIFAR-10 Batch 1:  loss:
# 0.844986
# Validation Accuracy:
# 0.6706
# Epoch 60, CIFAR-10 Batch 2:  loss:
# 0.784858
# Validation Accuracy:
# 0.6716
# Epoch 60, CIFAR-10 Batch 3:  loss:
# 0.71002
# Validation Accuracy:
# 0.665
# Epoch 60, CIFAR-10 Batch 4:  loss:
# 0.726741
# Validation Accuracy:
# 0.6696
# Epoch 60, CIFAR-10 Batch 5:  loss:
# 0.776249
# Validation Accuracy:
# 0.6642
# Epoch 61, CIFAR-10 Batch 1:  loss:
# 0.836144
# Validation Accuracy:
# 0.6704
# Epoch 61, CIFAR-10 Batch 2:  loss:
# 0.775077
# Validation Accuracy:
# 0.6722
# Epoch 61, CIFAR-10 Batch 3:  loss:
# 0.706543
# Validation Accuracy:
# 0.6704
# Epoch 61, CIFAR-10 Batch 4:  loss:
# 0.739562
# Validation Accuracy:
# 0.664
# Epoch 61, CIFAR-10 Batch 5:  loss:
# 0.767899
# Validation Accuracy:
# 0.6606
# Epoch 62, CIFAR-10 Batch 1:  loss:
# 0.829655
# Validation Accuracy:
# 0.6688
# Epoch 62, CIFAR-10 Batch 2:  loss:
# 0.773516
# Validation Accuracy:
# 0.6702
# Epoch 62, CIFAR-10 Batch 3:  loss:
# 0.698193
# Validation Accuracy:
# 0.6644
# Epoch 62, CIFAR-10 Batch 4:  loss:
# 0.699961
# Validation Accuracy:
# 0.6702
# Epoch 62, CIFAR-10 Batch 5:  loss:
# 0.753099
# Validation Accuracy:
# 0.6634
# Epoch 63, CIFAR-10 Batch 1:  loss:
# 0.816333
# Validation Accuracy:
# 0.67
# Epoch 63, CIFAR-10 Batch 2:  loss:
# 0.768072
# Validation Accuracy:
# 0.6724
# Epoch 63, CIFAR-10 Batch 3:  loss:
# 0.715247
# Validation Accuracy:
# 0.6672
# Epoch 63, CIFAR-10 Batch 4:  loss:
# 0.716814
# Validation Accuracy:
# 0.659
# Epoch 63, CIFAR-10 Batch 5:  loss:
# 0.757641
# Validation Accuracy:
# 0.6694
# Epoch 64, CIFAR-10 Batch 1:  loss:
# 0.835689
# Validation Accuracy:
# 0.6686
# Epoch 64, CIFAR-10 Batch 2:  loss:
# 0.755845
# Validation Accuracy:
# 0.6714
# Epoch 64, CIFAR-10 Batch 3:  loss:
# 0.704975
# Validation Accuracy:
# 0.6702
# Epoch 64, CIFAR-10 Batch 4:  loss:
# 0.709897
# Validation Accuracy:
# 0.664
# Epoch 64, CIFAR-10 Batch 5:  loss:
# 0.768257
# Validation Accuracy:
# 0.667
# Epoch 65, CIFAR-10 Batch 1:  loss:
# 0.824787
# Validation Accuracy:
# 0.6722
# Epoch 65, CIFAR-10 Batch 2:  loss:
# 0.752589
# Validation Accuracy:
# 0.6798
# Epoch 65, CIFAR-10 Batch 3:  loss:
# 0.68735
# Validation Accuracy:
# 0.6672
# Epoch 65, CIFAR-10 Batch 4:  loss:
# 0.686187
# Validation Accuracy:
# 0.6764
# Epoch 65, CIFAR-10 Batch 5:  loss:
# 0.761346
# Validation Accuracy:
# 0.66
# Epoch 66, CIFAR-10 Batch 1:  loss:
# 0.811242
# Validation Accuracy:
# 0.6756
# Epoch 66, CIFAR-10 Batch 2:  loss:
# 0.740224
# Validation Accuracy:
# 0.676
# Epoch 66, CIFAR-10 Batch 3:  loss:
# 0.697281
# Validation Accuracy:
# 0.6656
# Epoch 66, CIFAR-10 Batch 4:  loss:
# 0.681298
# Validation Accuracy:
# 0.674
# Epoch 66, CIFAR-10 Batch 5:  loss:
# 0.720468
# Validation Accuracy:
# 0.679
# Epoch 67, CIFAR-10 Batch 1:  loss:
# 0.804181
# Validation Accuracy:
# 0.6746
# Epoch 67, CIFAR-10 Batch 2:  loss:
# 0.749027
# Validation Accuracy:
# 0.669
# Epoch 67, CIFAR-10 Batch 3:  loss:
# 0.705833
# Validation Accuracy:
# 0.6638
# Epoch 67, CIFAR-10 Batch 4:  loss:
# 0.691782
# Validation Accuracy:
# 0.6746
# Epoch 67, CIFAR-10 Batch 5:  loss:
# 0.753616
# Validation Accuracy:
# 0.6718
# Epoch 68, CIFAR-10 Batch 1:  loss:
# 0.818828
# Validation Accuracy:
# 0.6636
# Epoch 68, CIFAR-10 Batch 2:  loss:
# 0.752456
# Validation Accuracy:
# 0.6836
# Epoch 68, CIFAR-10 Batch 3:  loss:
# 0.674579
# Validation Accuracy:
# 0.6782
# Epoch 68, CIFAR-10 Batch 4:  loss:
# 0.687011
# Validation Accuracy:
# 0.672
# Epoch 68, CIFAR-10 Batch 5:  loss:
# 0.742155
# Validation Accuracy:
# 0.6768
# Epoch 69, CIFAR-10 Batch 1:  loss:
# 0.796601
# Validation Accuracy:
# 0.6718
# Epoch 69, CIFAR-10 Batch 2:  loss:
# 0.755708
# Validation Accuracy:
# 0.6744
# Epoch 69, CIFAR-10 Batch 3:  loss:
# 0.685586
# Validation Accuracy:
# 0.6734
# Epoch 69, CIFAR-10 Batch 4:  loss:
# 0.683432
# Validation Accuracy:
# 0.6756
# Epoch 69, CIFAR-10 Batch 5:  loss:
# 0.733653
# Validation Accuracy:
# 0.6684
# Epoch 70, CIFAR-10 Batch 1:  loss:
# 0.792481
# Validation Accuracy:
# 0.6704
# Epoch 70, CIFAR-10 Batch 2:  loss:
# 0.73891
# Validation Accuracy:
# 0.6706
# Epoch 70, CIFAR-10 Batch 3:  loss:
# 0.694922
# Validation Accuracy:
# 0.6758
# Epoch 70, CIFAR-10 Batch 4:  loss:
# 0.675106
# Validation Accuracy:
# 0.6808
# Epoch 70, CIFAR-10 Batch 5:  loss:
# 0.71702
# Validation Accuracy:
# 0.6728
# Epoch 71, CIFAR-10 Batch 1:  loss:
# 0.77938
# Validation Accuracy:
# 0.6702
# Epoch 71, CIFAR-10 Batch 2:  loss:
# 0.721291
# Validation Accuracy:
# 0.6786
# Epoch 71, CIFAR-10 Batch 3:  loss:
# 0.680449
# Validation Accuracy:
# 0.6744
# Epoch 71, CIFAR-10 Batch 4:  loss:
# 0.67597
# Validation Accuracy:
# 0.6744
# Epoch 71, CIFAR-10 Batch 5:  loss:
# 0.735192
# Validation Accuracy:
# 0.6686
# Epoch 72, CIFAR-10 Batch 1:  loss:
# 0.788168
# Validation Accuracy:
# 0.6752
# Epoch 72, CIFAR-10 Batch 2:  loss:
# 0.733565
# Validation Accuracy:
# 0.6814
# Epoch 72, CIFAR-10 Batch 3:  loss:
# 0.678227
# Validation Accuracy:
# 0.6712
# Epoch 72, CIFAR-10 Batch 4:  loss:
# 0.681574
# Validation Accuracy:
# 0.676
# Epoch 72, CIFAR-10 Batch 5:  loss:
# 0.725761
# Validation Accuracy:
# 0.6738
# Epoch 73, CIFAR-10 Batch 1:  loss:
# 0.792085
# Validation Accuracy:
# 0.6774
# Epoch 73, CIFAR-10 Batch 2:  loss:
# 0.726914
# Validation Accuracy:
# 0.68
# Epoch 73, CIFAR-10 Batch 3:  loss:
# 0.669093
# Validation Accuracy:
# 0.6712
# Epoch 73, CIFAR-10 Batch 4:  loss:
# 0.657164
# Validation Accuracy:
# 0.6756
# Epoch 73, CIFAR-10 Batch 5:  loss:
# 0.713922
# Validation Accuracy:
# 0.6706
# Epoch 74, CIFAR-10 Batch 1:  loss:
# 0.799624
# Validation Accuracy:
# 0.6714
# Epoch 74, CIFAR-10 Batch 2:  loss:
# 0.717233
# Validation Accuracy:
# 0.6794
# Epoch 74, CIFAR-10 Batch 3:  loss:
# 0.67477
# Validation Accuracy:
# 0.6688
# Epoch 74, CIFAR-10 Batch 4:  loss:
# 0.660514
# Validation Accuracy:
# 0.6728
# Epoch 74, CIFAR-10 Batch 5:  loss:
# 0.712379
# Validation Accuracy:
# 0.6684
# Epoch 75, CIFAR-10 Batch 1:  loss:
# 0.766676
# Validation Accuracy:
# 0.6784
# Epoch 75, CIFAR-10 Batch 2:  loss:
# 0.719196
# Validation Accuracy:
# 0.674
# Epoch 75, CIFAR-10 Batch 3:  loss:
# 0.677223
# Validation Accuracy:
# 0.6788
# Epoch 75, CIFAR-10 Batch 4:  loss:
# 0.653304
# Validation Accuracy:
# 0.6746
# Epoch 75, CIFAR-10 Batch 5:  loss:
# 0.696845
# Validation Accuracy:
# 0.671
# Epoch 76, CIFAR-10 Batch 1:  loss:
# 0.778494
# Validation Accuracy:
# 0.673
# Epoch 76, CIFAR-10 Batch 2:  loss:
# 0.707123
# Validation Accuracy:
# 0.6816
# Epoch 76, CIFAR-10 Batch 3:  loss:
# 0.640718
# Validation Accuracy:
# 0.6792
# Epoch 76, CIFAR-10 Batch 4:  loss:
# 0.665635
# Validation Accuracy:
# 0.676
# Epoch 76, CIFAR-10 Batch 5:  loss:
# 0.693878
# Validation Accuracy:
# 0.673
# Epoch 77, CIFAR-10 Batch 1:  loss:
# 0.752752
# Validation Accuracy:
# 0.6804
# Epoch 77, CIFAR-10 Batch 2:  loss:
# 0.718888
# Validation Accuracy:
# 0.6814
# Epoch 77, CIFAR-10 Batch 3:  loss:
# 0.657741
# Validation Accuracy:
# 0.6838
# Epoch 77, CIFAR-10 Batch 4:  loss:
# 0.656981
# Validation Accuracy:
# 0.6796
# Epoch 77, CIFAR-10 Batch 5:  loss:
# 0.723053
# Validation Accuracy:
# 0.6772
# Epoch 78, CIFAR-10 Batch 1:  loss:
# 0.760635
# Validation Accuracy:
# 0.6756
# Epoch 78, CIFAR-10 Batch 2:  loss:
# 0.692962
# Validation Accuracy:
# 0.687
# Epoch 78, CIFAR-10 Batch 3:  loss:
# 0.634571
# Validation Accuracy:
# 0.6786
# Epoch 78, CIFAR-10 Batch 4:  loss:
# 0.653155
# Validation Accuracy:
# 0.6756
# Epoch 78, CIFAR-10 Batch 5:  loss:
# 0.695205
# Validation Accuracy:
# 0.6736
# Epoch 79, CIFAR-10 Batch 1:  loss:
# 0.723494
# Validation Accuracy:
# 0.6824
# Epoch 79, CIFAR-10 Batch 2:  loss:
# 0.696632
# Validation Accuracy:
# 0.6826
# Epoch 79, CIFAR-10 Batch 3:  loss:
# 0.628463
# Validation Accuracy:
# 0.6756
# Epoch 79, CIFAR-10 Batch 4:  loss:
# 0.671935
# Validation Accuracy:
# 0.6706
# Epoch 79, CIFAR-10 Batch 5:  loss:
# 0.69297
# Validation Accuracy:
# 0.6748
# Epoch 80, CIFAR-10 Batch 1:  loss:
# 0.752244
# Validation Accuracy:
# 0.6768
# Epoch 80, CIFAR-10 Batch 2:  loss:
# 0.697985
# Validation Accuracy:
# 0.6814
# Epoch 80, CIFAR-10 Batch 3:  loss:
# 0.634048
# Validation Accuracy:
# 0.6796
# Epoch 80, CIFAR-10 Batch 4:  loss:
# 0.63756
# Validation Accuracy:
# 0.682
# Epoch 80, CIFAR-10 Batch 5:  loss:
# 0.693867
# Validation Accuracy:
# 0.6738
# Epoch 81, CIFAR-10 Batch 1:  loss:
# 0.752846
# Validation Accuracy:
# 0.6796
# Epoch 81, CIFAR-10 Batch 2:  loss:
# 0.692138
# Validation Accuracy:
# 0.6848
# Epoch 81, CIFAR-10 Batch 3:  loss:
# 0.618011
# Validation Accuracy:
# 0.6846
# Epoch 81, CIFAR-10 Batch 4:  loss:
# 0.660399
# Validation Accuracy:
# 0.6862
# Epoch 81, CIFAR-10 Batch 5:  loss:
# 0.687854
# Validation Accuracy:
# 0.6784
# Epoch 82, CIFAR-10 Batch 1:  loss:
# 0.759316
# Validation Accuracy:
# 0.678
# Epoch 82, CIFAR-10 Batch 2:  loss:
# 0.693903
# Validation Accuracy:
# 0.681
# Epoch 82, CIFAR-10 Batch 3:  loss:
# 0.634148
# Validation Accuracy:
# 0.6758
# Epoch 82, CIFAR-10 Batch 4:  loss:
# 0.658041
# Validation Accuracy:
# 0.675
# Epoch 82, CIFAR-10 Batch 5:  loss:
# 0.701635
# Validation Accuracy:
# 0.6732
# Epoch 83, CIFAR-10 Batch 1:  loss:
# 0.739909
# Validation Accuracy:
# 0.6866
# Epoch 83, CIFAR-10 Batch 2:  loss:
# 0.691606
# Validation Accuracy:
# 0.6878
# Epoch 83, CIFAR-10 Batch 3:  loss:
# 0.639973
# Validation Accuracy:
# 0.6806
# Epoch 83, CIFAR-10 Batch 4:  loss:
# 0.635671
# Validation Accuracy:
# 0.682
# Epoch 83, CIFAR-10 Batch 5:  loss:
# 0.675017
# Validation Accuracy:
# 0.6736
# Epoch 84, CIFAR-10 Batch 1:  loss:
# 0.771092
# Validation Accuracy:
# 0.6698
# Epoch 84, CIFAR-10 Batch 2:  loss:
# 0.675737
# Validation Accuracy:
# 0.6896
# Epoch 84, CIFAR-10 Batch 3:  loss:
# 0.60848
# Validation Accuracy:
# 0.6822
# Epoch 84, CIFAR-10 Batch 4:  loss:
# 0.632902
# Validation Accuracy:
# 0.685
# Epoch 84, CIFAR-10 Batch 5:  loss:
# 0.693382
# Validation Accuracy:
# 0.6808
# Epoch 85, CIFAR-10 Batch 1:  loss:
# 0.734095
# Validation Accuracy:
# 0.6814
# Epoch 85, CIFAR-10 Batch 2:  loss:
# 0.667482
# Validation Accuracy:
# 0.6898
# Epoch 85, CIFAR-10 Batch 3:  loss:
# 0.634095
# Validation Accuracy:
# 0.6772
# Epoch 85, CIFAR-10 Batch 4:  loss:
# 0.654414
# Validation Accuracy:
# 0.6776
# Epoch 85, CIFAR-10 Batch 5:  loss:
# 0.67781
# Validation Accuracy:
# 0.6786
# Epoch 86, CIFAR-10 Batch 1:  loss:
# 0.711022
# Validation Accuracy:
# 0.6832
# Epoch 86, CIFAR-10 Batch 2:  loss:
# 0.682748
# Validation Accuracy:
# 0.6844
# Epoch 86, CIFAR-10 Batch 3:  loss:
# 0.618888
# Validation Accuracy:
# 0.6788
# Epoch 86, CIFAR-10 Batch 4:  loss:
# 0.624133
# Validation Accuracy:
# 0.6818
# Epoch 86, CIFAR-10 Batch 5:  loss:
# 0.653485
# Validation Accuracy:
# 0.6828
# Epoch 87, CIFAR-10 Batch 1:  loss:
# 0.717139
# Validation Accuracy:
# 0.684
# Epoch 87, CIFAR-10 Batch 2:  loss:
# 0.681146
# Validation Accuracy:
# 0.6876
# Epoch 87, CIFAR-10 Batch 3:  loss:
# 0.608681
# Validation Accuracy:
# 0.6822
# Epoch 87, CIFAR-10 Batch 4:  loss:
# 0.605934
# Validation Accuracy:
# 0.6898
# Epoch 87, CIFAR-10 Batch 5:  loss:
# 0.668886
# Validation Accuracy:
# 0.679
# Epoch 88, CIFAR-10 Batch 1:  loss:
# 0.726591
# Validation Accuracy:
# 0.6806
# Epoch 88, CIFAR-10 Batch 2:  loss:
# 0.668141
# Validation Accuracy:
# 0.684
# Epoch 88, CIFAR-10 Batch 3:  loss:
# 0.627084
# Validation Accuracy:
# 0.6796
# Epoch 88, CIFAR-10 Batch 4:  loss:
# 0.615138
# Validation Accuracy:
# 0.6846
# Epoch 88, CIFAR-10 Batch 5:  loss:
# 0.647148
# Validation Accuracy:
# 0.6758
# Epoch 89, CIFAR-10 Batch 1:  loss:
# 0.695349
# Validation Accuracy:
# 0.681
# Epoch 89, CIFAR-10 Batch 2:  loss:
# 0.660952
# Validation Accuracy:
# 0.6856
# Epoch 89, CIFAR-10 Batch 3:  loss:
# 0.61586
# Validation Accuracy:
# 0.6808
# Epoch 89, CIFAR-10 Batch 4:  loss:
# 0.62632
# Validation Accuracy:
# 0.6842
# Epoch 89, CIFAR-10 Batch 5:  loss:
# 0.631691
# Validation Accuracy:
# 0.689
# Epoch 90, CIFAR-10 Batch 1:  loss:
# 0.704425
# Validation Accuracy:
# 0.6832
# Epoch 90, CIFAR-10 Batch 2:  loss:
# 0.666364
# Validation Accuracy:
# 0.6924
# Epoch 90, CIFAR-10 Batch 3:  loss:
# 0.598182
# Validation Accuracy:
# 0.6834
# Epoch 90, CIFAR-10 Batch 4:  loss:
# 0.639508
# Validation Accuracy:
# 0.6742
# Epoch 90, CIFAR-10 Batch 5:  loss:
# 0.657029
# Validation Accuracy:
# 0.674
# Epoch 91, CIFAR-10 Batch 1:  loss:
# 0.702412
# Validation Accuracy:
# 0.6896
# Epoch 91, CIFAR-10 Batch 2:  loss:
# 0.662668
# Validation Accuracy:
# 0.6866
# Epoch 91, CIFAR-10 Batch 3:  loss:
# 0.581711
# Validation Accuracy:
# 0.6882
# Epoch 91, CIFAR-10 Batch 4:  loss:
# 0.615902
# Validation Accuracy:
# 0.6854
# Epoch 91, CIFAR-10 Batch 5:  loss:
# 0.645663
# Validation Accuracy:
# 0.6844
# Epoch 92, CIFAR-10 Batch 1:  loss:
# 0.682947
# Validation Accuracy:
# 0.6934
# Epoch 92, CIFAR-10 Batch 2:  loss:
# 0.660372
# Validation Accuracy:
# 0.6894
# Epoch 92, CIFAR-10 Batch 3:  loss:
# 0.582149
# Validation Accuracy:
# 0.6886
# Epoch 92, CIFAR-10 Batch 4:  loss:
# 0.607257
# Validation Accuracy:
# 0.6916
# Epoch 92, CIFAR-10 Batch 5:  loss:
# 0.62241
# Validation Accuracy:
# 0.687
# Epoch 93, CIFAR-10 Batch 1:  loss:
# 0.696487
# Validation Accuracy:
# 0.687
# Epoch 93, CIFAR-10 Batch 2:  loss:
# 0.644374
# Validation Accuracy:
# 0.6938
# Epoch 93, CIFAR-10 Batch 3:  loss:
# 0.585286
# Validation Accuracy:
# 0.6884
# Epoch 93, CIFAR-10 Batch 4:  loss:
# 0.604122
# Validation Accuracy:
# 0.689
# Epoch 93, CIFAR-10 Batch 5:  loss:
# 0.631052
# Validation Accuracy:
# 0.686
# Epoch 94, CIFAR-10 Batch 1:  loss:
# 0.674698
# Validation Accuracy:
# 0.6894
# Epoch 94, CIFAR-10 Batch 2:  loss:
# 0.656381
# Validation Accuracy:
# 0.696
# Epoch 94, CIFAR-10 Batch 3:  loss:
# 0.581253
# Validation Accuracy:
# 0.6884
# Epoch 94, CIFAR-10 Batch 4:  loss:
# 0.602831
# Validation Accuracy:
# 0.6852
# Epoch 94, CIFAR-10 Batch 5:  loss:
# 0.637404
# Validation Accuracy:
# 0.6848
# Epoch 95, CIFAR-10 Batch 1:  loss:
# 0.678036
# Validation Accuracy:
# 0.6862
# Epoch 95, CIFAR-10 Batch 2:  loss:
# 0.645782
# Validation Accuracy:
# 0.6862
# Epoch 95, CIFAR-10 Batch 3:  loss:
# 0.591981
# Validation Accuracy:
# 0.6826
# Epoch 95, CIFAR-10 Batch 4:  loss:
# 0.59959
# Validation Accuracy:
# 0.6906
# Epoch 95, CIFAR-10 Batch 5:  loss:
# 0.670372
# Validation Accuracy:
# 0.6788
# Epoch 96, CIFAR-10 Batch 1:  loss:
# 0.672503
# Validation Accuracy:
# 0.69
# Epoch 96, CIFAR-10 Batch 2:  loss:
# 0.636032
# Validation Accuracy:
# 0.6838
# Epoch 96, CIFAR-10 Batch 3:  loss:
# 0.579421
# Validation Accuracy:
# 0.6812
# Epoch 96, CIFAR-10 Batch 4:  loss:
# 0.595209
# Validation Accuracy:
# 0.6898
# Epoch 96, CIFAR-10 Batch 5:  loss:
# 0.62734
# Validation Accuracy:
# 0.6856
# Epoch 97, CIFAR-10 Batch 1:  loss:
# 0.663475
# Validation Accuracy:
# 0.6894
# Epoch 97, CIFAR-10 Batch 2:  loss:
# 0.647577
# Validation Accuracy:
# 0.688
# Epoch 97, CIFAR-10 Batch 3:  loss:
# 0.575648
# Validation Accuracy:
# 0.6866
# Epoch 97, CIFAR-10 Batch 4:  loss:
# 0.587985
# Validation Accuracy:
# 0.6908
# Epoch 97, CIFAR-10 Batch 5:  loss:
# 0.628928
# Validation Accuracy:
# 0.6854
# Epoch 98, CIFAR-10 Batch 1:  loss:
# 0.655109
# Validation Accuracy:
# 0.6892
# Epoch 98, CIFAR-10 Batch 2:  loss:
# 0.624302
# Validation Accuracy:
# 0.6914
# Epoch 98, CIFAR-10 Batch 3:  loss:
# 0.584935
# Validation Accuracy:
# 0.6866
# Epoch 98, CIFAR-10 Batch 4:  loss:
# 0.586452
# Validation Accuracy:
# 0.6904
# Epoch 98, CIFAR-10 Batch 5:  loss:
# 0.626281
# Validation Accuracy:
# 0.6866
# Epoch 99, CIFAR-10 Batch 1:  loss:
# 0.676677
# Validation Accuracy:
# 0.6886
# Epoch 99, CIFAR-10 Batch 2:  loss:
# 0.648687
# Validation Accuracy:
# 0.689
# Epoch 99, CIFAR-10 Batch 3:  loss:
# 0.581511
# Validation Accuracy:
# 0.6842
# Epoch 99, CIFAR-10 Batch 4:  loss:
# 0.607342
# Validation Accuracy:
# 0.6818
# Epoch 99, CIFAR-10 Batch 5:  loss:
# 0.626647
# Validation Accuracy:
# 0.6844
# Epoch 100, CIFAR-10 Batch 1:  loss:
# 0.657394
# Validation Accuracy:
# 0.6932
# Epoch 100, CIFAR-10 Batch 2:  loss:
# 0.623144
# Validation Accuracy:
# 0.6896
# Epoch 100, CIFAR-10 Batch 3:  loss:
# 0.561767
# Validation Accuracy:
# 0.6868
# Epoch 100, CIFAR-10 Batch 4:  loss:
# 0.574568
# Validation Accuracy:
# 0.6948
# Epoch 100, CIFAR-10 Batch 5:  loss:
# 0.614188
# Validation Accuracy:
# 0.6872
# Epoch 101, CIFAR-10 Batch 1:  loss:
# 0.65341
# Validation Accuracy:
# 0.686
# Epoch 101, CIFAR-10 Batch 2:  loss:
# 0.634043
# Validation Accuracy:
# 0.6954
# Epoch 101, CIFAR-10 Batch 3:  loss:
# 0.581683
# Validation Accuracy:
# 0.6916
# Epoch 101, CIFAR-10 Batch 4:  loss:
# 0.57261
# Validation Accuracy:
# 0.6898
# Epoch 101, CIFAR-10 Batch 5:  loss:
# 0.626824
# Validation Accuracy:
# 0.6812
# Epoch 102, CIFAR-10 Batch 1:  loss:
# 0.657888
# Validation Accuracy:
# 0.6872
# Epoch 102, CIFAR-10 Batch 2:  loss:
# 0.615743
# Validation Accuracy:
# 0.6988
# Epoch 102, CIFAR-10 Batch 3:  loss:
# 0.569191
# Validation Accuracy:
# 0.694
# Epoch 102, CIFAR-10 Batch 4:  loss:
# 0.556444
# Validation Accuracy:
# 0.6914
# Epoch 102, CIFAR-10 Batch 5:  loss:
# 0.613186
# Validation Accuracy:
# 0.6884
# Epoch 103, CIFAR-10 Batch 1:  loss:
# 0.656463
# Validation Accuracy:
# 0.69
# Epoch 103, CIFAR-10 Batch 2:  loss:
# 0.61975
# Validation Accuracy:
# 0.6946
# Epoch 103, CIFAR-10 Batch 3:  loss:
# 0.548536
# Validation Accuracy:
# 0.6946
# Epoch 103, CIFAR-10 Batch 4:  loss:
# 0.563773
# Validation Accuracy:
# 0.695
# Epoch 103, CIFAR-10 Batch 5:  loss:
# 0.605561
# Validation Accuracy:
# 0.6862
# Epoch 104, CIFAR-10 Batch 1:  loss:
# 0.654472
# Validation Accuracy:
# 0.691
# Epoch 104, CIFAR-10 Batch 2:  loss:
# 0.617096
# Validation Accuracy:
# 0.691
# Epoch 104, CIFAR-10 Batch 3:  loss:
# 0.550391
# Validation Accuracy:
# 0.6876
# Epoch 104, CIFAR-10 Batch 4:  loss:
# 0.577599
# Validation Accuracy:
# 0.689
# Epoch 104, CIFAR-10 Batch 5:  loss:
# 0.601471
# Validation Accuracy:
# 0.683
# Epoch 105, CIFAR-10 Batch 1:  loss:
# 0.641887
# Validation Accuracy:
# 0.6826
# Epoch 105, CIFAR-10 Batch 2:  loss:
# 0.617718
# Validation Accuracy:
# 0.6914
# Epoch 105, CIFAR-10 Batch 3:  loss:
# 0.554568
# Validation Accuracy:
# 0.693
# Epoch 105, CIFAR-10 Batch 4:  loss:
# 0.574027
# Validation Accuracy:
# 0.6882
# Epoch 105, CIFAR-10 Batch 5:  loss:
# 0.597023
# Validation Accuracy:
# 0.6888
# Epoch 106, CIFAR-10 Batch 1:  loss:
# 0.618048
# Validation Accuracy:
# 0.6986
# Epoch 106, CIFAR-10 Batch 2:  loss:
# 0.60082
# Validation Accuracy:
# 0.6968
# Epoch 106, CIFAR-10 Batch 3:  loss:
# 0.541094
# Validation Accuracy:
# 0.6936
# Epoch 106, CIFAR-10 Batch 4:  loss:
# 0.596831
# Validation Accuracy:
# 0.6796
# Epoch 106, CIFAR-10 Batch 5:  loss:
# 0.603712
# Validation Accuracy:
# 0.683
# Epoch 107, CIFAR-10 Batch 1:  loss:
# 0.624415
# Validation Accuracy:
# 0.691
# Epoch 107, CIFAR-10 Batch 2:  loss:
# 0.60483
# Validation Accuracy:
# 0.6944
# Epoch 107, CIFAR-10 Batch 3:  loss:
# 0.550466
# Validation Accuracy:
# 0.6914
# Epoch 107, CIFAR-10 Batch 4:  loss:
# 0.554323
# Validation Accuracy:
# 0.6924
# Epoch 107, CIFAR-10 Batch 5:  loss:
# 0.608406
# Validation Accuracy:
# 0.6884
# Epoch 108, CIFAR-10 Batch 1:  loss:
# 0.629349
# Validation Accuracy:
# 0.6928
# Epoch 108, CIFAR-10 Batch 2:  loss:
# 0.601859
# Validation Accuracy:
# 0.6972
# Epoch 108, CIFAR-10 Batch 3:  loss:
# 0.544157
# Validation Accuracy:
# 0.6906
# Epoch 108, CIFAR-10 Batch 4:  loss:
# 0.552548
# Validation Accuracy:
# 0.6966
# Epoch 108, CIFAR-10 Batch 5:  loss:
# 0.595333
# Validation Accuracy:
# 0.6904
# Epoch 109, CIFAR-10 Batch 1:  loss:
# 0.617552
# Validation Accuracy:
# 0.6934
# Epoch 109, CIFAR-10 Batch 2:  loss:
# 0.597732
# Validation Accuracy:
# 0.7012
# Epoch 109, CIFAR-10 Batch 3:  loss:
# 0.547554
# Validation Accuracy:
# 0.6904
# Epoch 109, CIFAR-10 Batch 4:  loss:
# 0.548749
# Validation Accuracy:
# 0.6882
# Epoch 109, CIFAR-10 Batch 5:  loss:
# 0.606407
# Validation Accuracy:
# 0.6864
# Epoch 110, CIFAR-10 Batch 1:  loss:
# 0.610519
# Validation Accuracy:
# 0.7022
# Epoch 110, CIFAR-10 Batch 2:  loss:
# 0.583769
# Validation Accuracy:
# 0.6952
# Epoch 110, CIFAR-10 Batch 3:  loss:
# 0.515996
# Validation Accuracy:
# 0.6916
# Epoch 110, CIFAR-10 Batch 4:  loss:
# 0.56676
# Validation Accuracy:
# 0.6906
# Epoch 110, CIFAR-10 Batch 5:  loss:
# 0.597462
# Validation Accuracy:
# 0.6952
# Epoch 111, CIFAR-10 Batch 1:  loss:
# 0.611706
# Validation Accuracy:
# 0.694
# Epoch 111, CIFAR-10 Batch 2:  loss:
# 0.579372
# Validation Accuracy:
# 0.7008
# Epoch 111, CIFAR-10 Batch 3:  loss:
# 0.539104
# Validation Accuracy:
# 0.6926
# Epoch 111, CIFAR-10 Batch 4:  loss:
# 0.553486
# Validation Accuracy:
# 0.688
# Epoch 111, CIFAR-10 Batch 5:  loss:
# 0.592703
# Validation Accuracy:
# 0.6928
# Epoch 112, CIFAR-10 Batch 1:  loss:
# 0.645155
# Validation Accuracy:
# 0.6918
# Epoch 112, CIFAR-10 Batch 2:  loss:
# 0.590806
# Validation Accuracy:
# 0.6944
# Epoch 112, CIFAR-10 Batch 3:  loss:
# 0.544616
# Validation Accuracy:
# 0.6908
# Epoch 112, CIFAR-10 Batch 4:  loss:
# 0.556751
# Validation Accuracy:
# 0.6916
# Epoch 112, CIFAR-10 Batch 5:  loss:
# 0.592809
# Validation Accuracy:
# 0.6958
# Epoch 113, CIFAR-10 Batch 1:  loss:
# 0.621848
# Validation Accuracy:
# 0.6904
# Epoch 113, CIFAR-10 Batch 2:  loss:
# 0.593285
# Validation Accuracy:
# 0.6976
# Epoch 113, CIFAR-10 Batch 3:  loss:
# 0.545467
# Validation Accuracy:
# 0.6942
# Epoch 113, CIFAR-10 Batch 4:  loss:
# 0.562745
# Validation Accuracy:
# 0.6928
# Epoch 113, CIFAR-10 Batch 5:  loss:
# 0.582256
# Validation Accuracy:
# 0.6914
# Epoch 114, CIFAR-10 Batch 1:  loss:
# 0.623472
# Validation Accuracy:
# 0.6906
# Epoch 114, CIFAR-10 Batch 2:  loss:
# 0.573491
# Validation Accuracy:
# 0.7028
# Epoch 114, CIFAR-10 Batch 3:  loss:
# 0.52559
# Validation Accuracy:
# 0.6956
# Epoch 114, CIFAR-10 Batch 4:  loss:
# 0.538649
# Validation Accuracy:
# 0.6938
# Epoch 114, CIFAR-10 Batch 5:  loss:
# 0.569783
# Validation Accuracy:
# 0.696
# Epoch 115, CIFAR-10 Batch 1:  loss:
# 0.611152
# Validation Accuracy:
# 0.687
# Epoch 115, CIFAR-10 Batch 2:  loss:
# 0.577991
# Validation Accuracy:
# 0.6938
# Epoch 115, CIFAR-10 Batch 3:  loss:
# 0.545118
# Validation Accuracy:
# 0.6922
# Epoch 115, CIFAR-10 Batch 4:  loss:
# 0.550976
# Validation Accuracy:
# 0.699
# Epoch 115, CIFAR-10 Batch 5:  loss:
# 0.585234
# Validation Accuracy:
# 0.6952
# Epoch 116, CIFAR-10 Batch 1:  loss:
# 0.609857
# Validation Accuracy:
# 0.6894
# Epoch 116, CIFAR-10 Batch 2:  loss:
# 0.553016
# Validation Accuracy:
# 0.6988
# Epoch 116, CIFAR-10 Batch 3:  loss:
# 0.539933
# Validation Accuracy:
# 0.691
# Epoch 116, CIFAR-10 Batch 4:  loss:
# 0.535993
# Validation Accuracy:
# 0.6908
# Epoch 116, CIFAR-10 Batch 5:  loss:
# 0.583672
# Validation Accuracy:
# 0.694
# Epoch 117, CIFAR-10 Batch 1:  loss:
# 0.587133
# Validation Accuracy:
# 0.6988
# Epoch 117, CIFAR-10 Batch 2:  loss:
# 0.575824
# Validation Accuracy:
# 0.7014
# Epoch 117, CIFAR-10 Batch 3:  loss:
# 0.52997
# Validation Accuracy:
# 0.6976
# Epoch 117, CIFAR-10 Batch 4:  loss:
# 0.537786
# Validation Accuracy:
# 0.6962
# Epoch 117, CIFAR-10 Batch 5:  loss:
# 0.563392
# Validation Accuracy:
# 0.6912
# Epoch 118, CIFAR-10 Batch 1:  loss:
# 0.601428
# Validation Accuracy:
# 0.6938
# Epoch 118, CIFAR-10 Batch 2:  loss:
# 0.574491
# Validation Accuracy:
# 0.697
# Epoch 118, CIFAR-10 Batch 3:  loss:
# 0.511679
# Validation Accuracy:
# 0.6962
# Epoch 118, CIFAR-10 Batch 4:  loss:
# 0.531424
# Validation Accuracy:
# 0.7036
# Epoch 118, CIFAR-10 Batch 5:  loss:
# 0.561932
# Validation Accuracy:
# 0.687
# Epoch 119, CIFAR-10 Batch 1:  loss:
# 0.580707
# Validation Accuracy:
# 0.6936
# Epoch 119, CIFAR-10 Batch 2:  loss:
# 0.574328
# Validation Accuracy:
# 0.691
# Epoch 119, CIFAR-10 Batch 3:  loss:
# 0.507944
# Validation Accuracy:
# 0.6976
# Epoch 119, CIFAR-10 Batch 4:  loss:
# 0.524828
# Validation Accuracy:
# 0.6986
# Epoch 119, CIFAR-10 Batch 5:  loss:
# 0.555711
# Validation Accuracy:
# 0.695
# Epoch 120, CIFAR-10 Batch 1:  loss:
# 0.592862
# Validation Accuracy:
# 0.6938
# Epoch 120, CIFAR-10 Batch 2:  loss:
# 0.565918
# Validation Accuracy:
# 0.7006
# Epoch 120, CIFAR-10 Batch 3:  loss:
# 0.515642
# Validation Accuracy:
# 0.691
# Epoch 120, CIFAR-10 Batch 4:  loss:
# 0.53354
# Validation Accuracy:
# 0.6956
# Epoch 120, CIFAR-10 Batch 5:  loss:
# 0.544102
# Validation Accuracy:
# 0.6948
# Epoch 121, CIFAR-10 Batch 1:  loss:
# 0.587429
# Validation Accuracy:
# 0.6946
# Epoch 121, CIFAR-10 Batch 2:  loss:
# 0.568713
# Validation Accuracy:
# 0.7006
# Epoch 121, CIFAR-10 Batch 3:  loss:
# 0.508748
# Validation Accuracy:
# 0.702
# Epoch 121, CIFAR-10 Batch 4:  loss:
# 0.533699
# Validation Accuracy:
# 0.695
# Epoch 121, CIFAR-10 Batch 5:  loss:
# 0.557949
# Validation Accuracy:
# 0.6918
# Epoch 122, CIFAR-10 Batch 1:  loss:
# 0.584139
# Validation Accuracy:
# 0.7034
# Epoch 122, CIFAR-10 Batch 2:  loss:
# 0.569375
# Validation Accuracy:
# 0.702
# Epoch 122, CIFAR-10 Batch 3:  loss:
# 0.53547
# Validation Accuracy:
# 0.6954
# Epoch 122, CIFAR-10 Batch 4:  loss:
# 0.512872
# Validation Accuracy:
# 0.703
# Epoch 122, CIFAR-10 Batch 5:  loss:
# 0.563011
# Validation Accuracy:
# 0.6882
# Epoch 123, CIFAR-10 Batch 1:  loss:
# 0.590612
# Validation Accuracy:
# 0.6938
# Epoch 123, CIFAR-10 Batch 2:  loss:
# 0.565273
# Validation Accuracy:
# 0.6926
# Epoch 123, CIFAR-10 Batch 3:  loss:
# 0.51723
# Validation Accuracy:
# 0.7006
# Epoch 123, CIFAR-10 Batch 4:  loss:
# 0.53324
# Validation Accuracy:
# 0.6902
# Epoch 123, CIFAR-10 Batch 5:  loss:
# 0.594804
# Validation Accuracy:
# 0.6918
# Epoch 124, CIFAR-10 Batch 1:  loss:
# 0.574766
# Validation Accuracy:
# 0.7012
# Epoch 124, CIFAR-10 Batch 2:  loss:
# 0.565298
# Validation Accuracy:
# 0.6954
# Epoch 124, CIFAR-10 Batch 3:  loss:
# 0.515164
# Validation Accuracy:
# 0.6942
# Epoch 124, CIFAR-10 Batch 4:  loss:
# 0.522171
# Validation Accuracy:
# 0.694
# Epoch 124, CIFAR-10 Batch 5:  loss:
# 0.544044
# Validation Accuracy:
# 0.693
# Epoch 125, CIFAR-10 Batch 1:  loss:
# 0.592571
# Validation Accuracy:
# 0.694
# Epoch 125, CIFAR-10 Batch 2:  loss:
# 0.580379
# Validation Accuracy:
# 0.6982
# Epoch 125, CIFAR-10 Batch 3:  loss:
# 0.515977
# Validation Accuracy:
# 0.6938
# Epoch 125, CIFAR-10 Batch 4:  loss:
# 0.5333
# Validation Accuracy:
# 0.6918
# Epoch 125, CIFAR-10 Batch 5:  loss:
# 0.550578
# Validation Accuracy:
# 0.6982
# Epoch 126, CIFAR-10 Batch 1:  loss:
# 0.580287
# Validation Accuracy:
# 0.701
# Epoch 126, CIFAR-10 Batch 2:  loss:
# 0.561819
# Validation Accuracy:
# 0.6958
# Epoch 126, CIFAR-10 Batch 3:  loss:
# 0.497955
# Validation Accuracy:
# 0.6984
# Epoch 126, CIFAR-10 Batch 4:  loss:
# 0.519981
# Validation Accuracy:
# 0.6924
# Epoch 126, CIFAR-10 Batch 5:  loss:
# 0.540986
# Validation Accuracy:
# 0.6972
# Epoch 127, CIFAR-10 Batch 1:  loss:
# 0.560347
# Validation Accuracy:
# 0.7022
# Epoch 127, CIFAR-10 Batch 2:  loss:
# 0.544246
# Validation Accuracy:
# 0.703
# Epoch 127, CIFAR-10 Batch 3:  loss:
# 0.502723
# Validation Accuracy:
# 0.6958
# Epoch 127, CIFAR-10 Batch 4:  loss:
# 0.513746
# Validation Accuracy:
# 0.6948
# Epoch 127, CIFAR-10 Batch 5:  loss:
# 0.536595
# Validation Accuracy:
# 0.6942
# Epoch 128, CIFAR-10 Batch 1:  loss:
# 0.568793
# Validation Accuracy:
# 0.6966
# Epoch 128, CIFAR-10 Batch 2:  loss:
# 0.565693
# Validation Accuracy:
# 0.6996
# Epoch 128, CIFAR-10 Batch 3:  loss:
# 0.524288
# Validation Accuracy:
# 0.6902
# Epoch 128, CIFAR-10 Batch 4:  loss:
# 0.521185
# Validation Accuracy:
# 0.6936
# Epoch 128, CIFAR-10 Batch 5:  loss:
# 0.542688
# Validation Accuracy:
# 0.6948
# Epoch 129, CIFAR-10 Batch 1:  loss:
# 0.561445
# Validation Accuracy:
# 0.6992
# Epoch 129, CIFAR-10 Batch 2:  loss:
# 0.516066
# Validation Accuracy:
# 0.7032
# Epoch 129, CIFAR-10 Batch 3:  loss:
# 0.50031
# Validation Accuracy:
# 0.694
# Epoch 129, CIFAR-10 Batch 4:  loss:
# 0.518003
# Validation Accuracy:
# 0.6918
# Epoch 129, CIFAR-10 Batch 5:  loss:
# 0.560625
# Validation Accuracy:
# 0.6876
# Epoch 130, CIFAR-10 Batch 1:  loss:
# 0.579796
# Validation Accuracy:
# 0.6924
# Epoch 130, CIFAR-10 Batch 2:  loss:
# 0.540287
# Validation Accuracy:
# 0.7048
# Epoch 130, CIFAR-10 Batch 3:  loss:
# 0.488327
# Validation Accuracy:
# 0.699
# Epoch 130, CIFAR-10 Batch 4:  loss:
# 0.513372
# Validation Accuracy:
# 0.6934
# Epoch 130, CIFAR-10 Batch 5:  loss:
# 0.531431
# Validation Accuracy:
# 0.6946
# Epoch 131, CIFAR-10 Batch 1:  loss:
# 0.578436
# Validation Accuracy:
# 0.6902
# Epoch 131, CIFAR-10 Batch 2:  loss:
# 0.538392
# Validation Accuracy:
# 0.7034
# Epoch 131, CIFAR-10 Batch 3:  loss:
# 0.507775
# Validation Accuracy:
# 0.6932
# Epoch 131, CIFAR-10 Batch 4:  loss:
# 0.521139
# Validation Accuracy:
# 0.6924
# Epoch 131, CIFAR-10 Batch 5:  loss:
# 0.527076
# Validation Accuracy:
# 0.6988
# Epoch 132, CIFAR-10 Batch 1:  loss:
# 0.542611
# Validation Accuracy:
# 0.7026
# Epoch 132, CIFAR-10 Batch 2:  loss:
# 0.537707
# Validation Accuracy:
# 0.7064
# Epoch 132, CIFAR-10 Batch 3:  loss:
# 0.498797
# Validation Accuracy:
# 0.6994
# Epoch 132, CIFAR-10 Batch 4:  loss:
# 0.536568
# Validation Accuracy:
# 0.689
# Epoch 132, CIFAR-10 Batch 5:  loss:
# 0.533889
# Validation Accuracy:
# 0.7012
# Epoch 133, CIFAR-10 Batch 1:  loss:
# 0.560209
# Validation Accuracy:
# 0.7036
# Epoch 133, CIFAR-10 Batch 2:  loss:
# 0.552307
# Validation Accuracy:
# 0.6996
# Epoch 133, CIFAR-10 Batch 3:  loss:
# 0.4989
# Validation Accuracy:
# 0.6958
# Epoch 133, CIFAR-10 Batch 4:  loss:
# 0.509131
# Validation Accuracy:
# 0.6934
# Epoch 133, CIFAR-10 Batch 5:  loss:
# 0.531073
# Validation Accuracy:
# 0.697
# Epoch 134, CIFAR-10 Batch 1:  loss:
# 0.546113
# Validation Accuracy:
# 0.6972
# Epoch 134, CIFAR-10 Batch 2:  loss:
# 0.514789
# Validation Accuracy:
# 0.7046
# Epoch 134, CIFAR-10 Batch 3:  loss:
# 0.495914
# Validation Accuracy:
# 0.6948
# Epoch 134, CIFAR-10 Batch 4:  loss:
# 0.496906
# Validation Accuracy:
# 0.699
# Epoch 134, CIFAR-10 Batch 5:  loss:
# 0.527277
# Validation Accuracy:
# 0.6882
# Epoch 135, CIFAR-10 Batch 1:  loss:
# 0.547681
# Validation Accuracy:
# 0.6992
# Epoch 135, CIFAR-10 Batch 2:  loss:
# 0.535177
# Validation Accuracy:
# 0.701
# Epoch 135, CIFAR-10 Batch 3:  loss:
# 0.499256
# Validation Accuracy:
# 0.6934
# Epoch 135, CIFAR-10 Batch 4:  loss:
# 0.510474
# Validation Accuracy:
# 0.6936
# Epoch 135, CIFAR-10 Batch 5:  loss:
# 0.517998
# Validation Accuracy:
# 0.6982
# Epoch 136, CIFAR-10 Batch 1:  loss:
# 0.534164
# Validation Accuracy:
# 0.7022
# Epoch 136, CIFAR-10 Batch 2:  loss:
# 0.520986
# Validation Accuracy:
# 0.698
# Epoch 136, CIFAR-10 Batch 3:  loss:
# 0.494263
# Validation Accuracy:
# 0.6928
# Epoch 136, CIFAR-10 Batch 4:  loss:
# 0.494711
# Validation Accuracy:
# 0.7032
# Epoch 136, CIFAR-10 Batch 5:  loss:
# 0.526817
# Validation Accuracy:
# 0.696
# Epoch 137, CIFAR-10 Batch 1:  loss:
# 0.54341
# Validation Accuracy:
# 0.6986
# Epoch 137, CIFAR-10 Batch 2:  loss:
# 0.51546
# Validation Accuracy:
# 0.6996
# Epoch 137, CIFAR-10 Batch 3:  loss:
# 0.479735
# Validation Accuracy:
# 0.6974
# Epoch 137, CIFAR-10 Batch 4:  loss:
# 0.491398
# Validation Accuracy:
# 0.6994
# Epoch 137, CIFAR-10 Batch 5:  loss:
# 0.505724
# Validation Accuracy:
# 0.695
# Epoch 138, CIFAR-10 Batch 1:  loss:
# 0.534578
# Validation Accuracy:
# 0.6962
# Epoch 138, CIFAR-10 Batch 2:  loss:
# 0.520619
# Validation Accuracy:
# 0.7008
# Epoch 138, CIFAR-10 Batch 3:  loss:
# 0.490984
# Validation Accuracy:
# 0.6954
# Epoch 138, CIFAR-10 Batch 4:  loss:
# 0.483364
# Validation Accuracy:
# 0.6942
# Epoch 138, CIFAR-10 Batch 5:  loss:
# 0.513716
# Validation Accuracy:
# 0.6968
# Epoch 139, CIFAR-10 Batch 1:  loss:
# 0.544293
# Validation Accuracy:
# 0.6942
# Epoch 139, CIFAR-10 Batch 2:  loss:
# 0.529799
# Validation Accuracy:
# 0.709
# Epoch 139, CIFAR-10 Batch 3:  loss:
# 0.472441
# Validation Accuracy:
# 0.7018
# Epoch 139, CIFAR-10 Batch 4:  loss:
# 0.517694
# Validation Accuracy:
# 0.6888
# Epoch 139, CIFAR-10 Batch 5:  loss:
# 0.522642
# Validation Accuracy:
# 0.6958
# Epoch 140, CIFAR-10 Batch 1:  loss:
# 0.526181
# Validation Accuracy:
# 0.7012
# Epoch 140, CIFAR-10 Batch 2:  loss:
# 0.545547
# Validation Accuracy:
# 0.7
# Epoch 140, CIFAR-10 Batch 3:  loss:
# 0.493587
# Validation Accuracy:
# 0.698
# Epoch 140, CIFAR-10 Batch 4:  loss:
# 0.493228
# Validation Accuracy:
# 0.698
# Epoch 140, CIFAR-10 Batch 5:  loss:
# 0.517517
# Validation Accuracy:
# 0.6964

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7014993131160736

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
